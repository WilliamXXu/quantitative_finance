# %%
from bs4 import BeautifulSoup




# %run volatility_functions.ipynb
# %run correlation_functions.ipynb

# %%
latest_pval=lambda s: larger_proportion(s.dropna(),s[-1])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.cluster.hierarchy import dendrogram, linkage, leaves_list
from scipy.spatial.distance import pdist

def clustered_heatmap(df, 
                     method='ward', 
                     metric='euclidean',
                     cluster_rows=True, 
                     cluster_cols=True,
                     figsize=(12, 10),
                     cmap='viridis',
                     annot=False,
                     fmt='.2f',
                     use_seaborn_clustermap=True,
                     **kwargs):
    """
    Create a heatmap with hierarchical clustering of rows and/or columns.
    
    Parameters:
    -----------
    df : pandas.DataFrame
        Input dataframe to cluster and plot
    method : str, default 'ward'
        Linkage method for clustering ('ward', 'complete', 'average', 'single')
    metric : str, default 'euclidean'
        Distance metric ('euclidean', 'correlation', 'cosine', etc.)
    cluster_rows : bool, default True
        Whether to cluster rows
    cluster_cols : bool, default True
        Whether to cluster columns
    figsize : tuple, default (12, 10)
        Figure size (width, height)
    cmap : str, default 'viridis'
        Colormap for heatmap
    annot : bool, default False
        Whether to annotate cells with values
    fmt : str, default '.2f'
        String formatting for annotations
    use_seaborn_clustermap : bool, default True
        Whether to use seaborn's clustermap (recommended) or custom implementation
    **kwargs : additional arguments
        Additional arguments passed to seaborn plotting functions
    
    Returns:
    --------
    If use_seaborn_clustermap=True:
        ClusterGrid object from seaborn
    If use_seaborn_clustermap=False:
        tuple: (fig, clustered_df)
    """
    
    # Handle missing values
    df_clean = df.fillna(0)
    
    if use_seaborn_clustermap:
        # Use seaborn's clustermap - this ensures perfect alignment
        g = sns.clustermap(df_clean,
                          method=method,
                          metric=metric,
                          row_cluster=cluster_rows,
                          col_cluster=cluster_cols,
                          figsize=figsize,
                          cmap=cmap,
                          annot=annot,
                          fmt=fmt,
                          **kwargs)
        
        # Access the clustered dataframe
        clustered_df = df_clean.iloc[g.dendrogram_row.reordered_ind, 
                                    g.dendrogram_col.reordered_ind]
        
        return g, clustered_df
    
    else:
        # Custom implementation with proper alignment
        return _custom_clustered_heatmap(df_clean, method, metric, cluster_rows, 
                                       cluster_cols, figsize, cmap, annot, fmt, **kwargs)


def _custom_clustered_heatmap(df, method, metric, cluster_rows, cluster_cols, 
                             figsize, cmap, annot, fmt, **kwargs):
    """
    Custom implementation of clustered heatmap with proper dendrogram alignment.
    """
    
    # Initialize variables
    row_linkage = None
    col_linkage = None
    row_order = list(range(len(df)))
    col_order = list(range(len(df.columns)))
    
    # Perform hierarchical clustering for rows
    if cluster_rows and len(df) > 1:
        row_distances = pdist(df.values, metric=metric)
        row_linkage = linkage(row_distances, method=method)
        row_order = leaves_list(row_linkage)
    
    # Perform hierarchical clustering for columns
    if cluster_cols and len(df.columns) > 1:
        col_distances = pdist(df.T.values, metric=metric)
        col_linkage = linkage(col_distances, method=method)
        col_order = leaves_list(col_linkage)
    
    # Reorder dataframe
    clustered_df = df.iloc[row_order, col_order]
    
    # Create the plot
    fig = plt.figure(figsize=figsize)
    
    # Calculate subplot positions
    show_row_dendr = cluster_rows and len(df) > 1 and row_linkage is not None
    show_col_dendr = cluster_cols and len(df.columns) > 1 and col_linkage is not None
    
    dendr_height = 0.15 if show_col_dendr else 0
    dendr_width = 0.15 if show_row_dendr else 0
    
    # Main heatmap position
    heatmap_left = dendr_width + 0.05
    heatmap_bottom = 0.1
    heatmap_width = 0.85 - dendr_width
    heatmap_height = 0.85 - dendr_height
    
    # Create main heatmap
    ax_heatmap = fig.add_axes([heatmap_left, heatmap_bottom, 
                             heatmap_width, heatmap_height])
    
    # Plot heatmap with clustered data
    im = ax_heatmap.imshow(clustered_df.values, cmap=cmap, aspect='auto')
    
    # Set ticks and labels
    ax_heatmap.set_xticks(range(len(clustered_df.columns)))
    ax_heatmap.set_yticks(range(len(clustered_df.index)))
    ax_heatmap.set_xticklabels(clustered_df.columns, rotation=45, ha='right')
    ax_heatmap.set_yticklabels(clustered_df.index)
    
    # Add annotations if requested
    if annot:
        for i in range(len(clustered_df.index)):
            for j in range(len(clustered_df.columns)):
                text = ax_heatmap.text(j, i, format(clustered_df.iloc[i, j], fmt),
                                     ha="center", va="center", color="white" if clustered_df.iloc[i, j] < clustered_df.values.mean() else "black")
    
    # Add colorbar
    cbar_ax = fig.add_axes([0.92, heatmap_bottom, 0.03, heatmap_height])
    fig.colorbar(im, cax=cbar_ax)
    
    # Add column dendrogram
    if show_col_dendr:
        ax_col_dendr = fig.add_axes([heatmap_left, heatmap_bottom + heatmap_height + 0.02, 
                                   heatmap_width, dendr_height])
        
        # Create temporary dendrogram to get the correct ordering
        temp_dendr = dendrogram(col_linkage, no_plot=True)
        
        # Plot dendrogram with correct leaf order
        dendr_plot = dendrogram(col_linkage, ax=ax_col_dendr, 
                               orientation='top', 
                               color_threshold=0,
                               above_threshold_color='black')
        
        ax_col_dendr.set_xticks([])
        ax_col_dendr.set_yticks([])
        for spine in ax_col_dendr.spines.values():
            spine.set_visible(False)
    
    # Add row dendrogram
    if show_row_dendr:
        ax_row_dendr = fig.add_axes([0.05, heatmap_bottom, 
                                   dendr_width, heatmap_height])
        
        # Create temporary dendrogram to get the correct ordering
        temp_dendr = dendrogram(row_linkage, no_plot=True)
        
        # Plot dendrogram with correct leaf order
        dendr_plot = dendrogram(row_linkage, ax=ax_row_dendr, 
                               orientation='left',
                               color_threshold=0,
                               above_threshold_color='black')
        
        ax_row_dendr.set_xticks([])
        ax_row_dendr.set_yticks([])
        for spine in ax_row_dendr.spines.values():
            spine.set_visible(False)
    
    plt.tight_layout()
    return fig, clustered_df


# Simplified function using seaborn (recommended)
def quick_clustered_heatmap(df, **kwargs):
    """
    Quick and easy clustered heatmap using seaborn's clustermap.
    This is the recommended approach for most use cases.
    """
    defaults = {
        'method': 'ward',
        'metric': 'euclidean', 
        'figsize': (12, 10),
        'cmap': 'viridis',
        'annot': False
    }
    defaults.update(kwargs)
    
    g = sns.clustermap(df.fillna(0), **defaults)
    return g


# # Example usage function
# def example_usage():
#     """
#     Example of how to use the clustered_heatmap function
#     """
#     # Create sample data
#     np.random.seed(42)
#     data = np.random.randn(20, 15)
    
#     # Add some structure to make clustering meaningful
#     data[:10, :7] += 2  # Upper-left quadrant
#     data[10:, 7:] += 2  # Lower-right quadrant
    
#     # Create DataFrame
#     df = pd.DataFrame(data, 
#                      index=[f'Gene_{i}' for i in range(20)],
#                      columns=[f'Sample_{i}' for i in range(15)])
    
#     # Method 1: Using seaborn clustermap (recommended)
#     print("Creating clustered heatmap using seaborn...")
#     g = quick_clustered_heatmap(df, 
#                                cmap='RdBu_r',
#                                figsize=(12, 8))
#     plt.suptitle('Seaborn Clustered Heatmap', y=0.95)
#     plt.show()
    
#     # Method 2: Using custom function
#     print("Creating clustered heatmap using custom function...")
#     result = clustered_heatmap(df,
#                               method='ward',
#                               metric='euclidean',
#                               figsize=(14, 10),
#                               cmap='RdBu_r',
#                               annot=False,
#                               use_seaborn_clustermap=True)
    
#     if len(result) == 2:
#         g, clustered_df = result
#         plt.suptitle('Custom Clustered Heatmap', y=0.95)
#         plt.show()
#         return clustered_df
#     else:
#         g = result
#         return g

# # Uncomment to run example
# example_usage()

# %%
class FinanceDataCache:
    def __init__(self, cache_dir="finance_cache"):
        """Initialize the cache system"""
        self.cache_dir = Path(cache_dir)
        self.cache_dir.mkdir(exist_ok=True)
        
    def _get_cache_filename(self, symbol):
        """Generate cache filename for a symbol"""
        return self.cache_dir / f"{symbol.replace('/', '_').replace('^', '_')}.pkl"
    
    def _load_cached_data(self, symbol):
        """Load cached data for a symbol"""
        cache_file = self._get_cache_filename(symbol)
        if cache_file.exists():
            try:
                with open(cache_file, 'rb') as f:
                    cached_data = pickle.load(f)
                return cached_data['data'], cached_data['last_update']
            except Exception as e:
                print(f"Warning: Could not load cache for {symbol}: {e}")
                return None, None
        return None, None
    
    def _save_cached_data(self, symbol, data):
        """Save data to cache"""
        cache_file = self._get_cache_filename(symbol)
        try:
            cache_data = {
                'data': data,
                'last_update': datetime.now(),
                'symbol': symbol
            }
            with open(cache_file, 'wb') as f:
                pickle.dump(cache_data, f)
        except Exception as e:
            print(f"Warning: Could not save cache for {symbol}: {e}")
    
    def _merge_data(self, old_data, new_data):
        """Merge old cached data with new data, removing duplicates"""
        if old_data is None or old_data.empty:
            return new_data
        if new_data is None or new_data.empty:
            return old_data
            
        # Combine and remove duplicates, keeping the most recent data
        combined = pd.concat([old_data, new_data])
        combined = combined[~combined.index.duplicated(keep='last')]
        return combined.sort_index()
    
    def _determine_missing_ranges(self, cached_data, start_date, end_date):
        """Determine what date ranges need to be fetched"""
        if cached_data is None or cached_data.empty:
            return [(start_date, end_date)]
        
        cached_start = cached_data.index.min().date()
        cached_end = cached_data.index.max().date()
        
        # Convert string dates to datetime objects if needed
        if isinstance(start_date, str):
            start_date = datetime.strptime(start_date, '%Y-%m-%d').date()
        if isinstance(end_date, str):
            end_date = datetime.strptime(end_date, '%Y-%m-%d').date()
        
        ranges_to_fetch = []
        
        # Check if we need data before cached start
        if start_date < cached_start:
            # Fetch up to one day before cached start to avoid gaps
            fetch_end = cached_start - timedelta(days=1)
            ranges_to_fetch.append((start_date, fetch_end))
        
        # Check if we need data after cached end
        if end_date > cached_end:
            # Fetch from one day after cached end
            fetch_start = cached_end + timedelta(days=1)
            ranges_to_fetch.append((fetch_start, end_date))
        
        return ranges_to_fetch

# Global cache instance
_cache = FinanceDataCache()

def downloader(symbol, start_date, end_date, force_refresh=False, cache_dir="finance_cache"):
    """
    Enhanced function to download financial data with intelligent caching
    
    Parameters:
    -----------
    symbol : str
        Stock/asset symbol (e.g., 'AAPL', 'SPY')
    start_date : str or datetime
        Start date in 'YYYY-MM-DD' format
    end_date : str or datetime  
        End date in 'YYYY-MM-DD' format
    force_refresh : bool
        If True, ignore cache and download all data fresh
    cache_dir : str
        Directory to store cache files
        
    Returns:
    --------
    pandas.DataFrame
        Financial data with OHLCV columns
    """
    global _cache
    
    # Initialize cache with custom directory if specified
    if cache_dir != "finance_cache":
        _cache = FinanceDataCache(cache_dir)
    
    print(f"Processing data request for {symbol} from {start_date} to {end_date}...")
    
    if force_refresh:
        print(f"Force refresh enabled - downloading all data for {symbol}...")
        data = yf.download(symbol, start=start_date, end=end_date)
        _cache._save_cached_data(symbol, data)
        return data
    
    # Load cached data
    cached_data, last_update = _cache._load_cached_data(symbol)
    
    if cached_data is not None:
        print(f"Found cached data for {symbol} (last updated: {last_update.strftime('%Y-%m-%d %H:%M:%S')})")
        
        # Determine what ranges we need to fetch
        missing_ranges = _cache._determine_missing_ranges(cached_data, start_date, end_date)
        
        if not missing_ranges:
            print(f"All requested data for {symbol} available in cache!")
            # Filter cached data to requested range
            start_dt = pd.to_datetime(start_date)
            end_dt = pd.to_datetime(end_date)
            filtered_data = cached_data[(cached_data.index >= start_dt) & (cached_data.index <= end_dt)]
            return filtered_data
        
        # Fetch missing data
        all_new_data = pd.DataFrame()
        for range_start, range_end in missing_ranges:
            print(f"Fetching missing data for {symbol}: {range_start} to {range_end}")
            new_data = yf.download(symbol, start=range_start, end=range_end)
            if not new_data.empty:
                all_new_data = pd.concat([all_new_data, new_data])
        
        # Merge cached and new data
        complete_data = _cache._merge_data(cached_data, all_new_data)
        
    else:
        print(f"No cached data found for {symbol} - downloading all data...")
        complete_data = yf.download(symbol, start=start_date, end=end_date)
    
    # Save updated data to cache
    _cache._save_cached_data(symbol, complete_data)
    
    # Return only the requested date range
    start_dt = pd.to_datetime(start_date)
    end_dt = pd.to_datetime(end_date)
    filtered_data = complete_data[(complete_data.index >= start_dt) & (complete_data.index <= end_dt)]
    
    print(f"Data download complete for {symbol}. Shape: {filtered_data.shape}")
    return filtered_data

def clear_cache(symbol=None, cache_dir="finance_cache"):
    """
    Clear cache for specific symbol or all symbols
    
    Parameters:
    -----------
    symbol : str, optional
        Specific symbol to clear. If None, clears all cache
    cache_dir : str
        Cache directory path
    """
    cache = FinanceDataCache(cache_dir)
    
    if symbol:
        cache_file = cache._get_cache_filename(symbol)
        if cache_file.exists():
            cache_file.unlink()
            print(f"Cache cleared for {symbol}")
        else:
            print(f"No cache found for {symbol}")
    else:
        # Clear all cache files
        for cache_file in cache.cache_dir.glob("*.pkl"):
            cache_file.unlink()
        print("All cache files cleared")

def list_cached_symbols(cache_dir="finance_cache"):
    """
    List all symbols that have cached data
    
    Parameters:
    -----------
    cache_dir : str
        Cache directory path
        
    Returns:
    --------
    list
        List of cached symbols with their info
    """
    cache = FinanceDataCache(cache_dir)
    cached_symbols = []
    
    for cache_file in cache.cache_dir.glob("*.pkl"):
        try:
            with open(cache_file, 'rb') as f:
                cached_data = pickle.load(f)
            
            data = cached_data['data']
            symbol_info = {
                'symbol': cached_data['symbol'],
                'last_update': cached_data['last_update'],
                'date_range': f"{data.index.min().date()} to {data.index.max().date()}",
                'records': len(data),
                'file_size': f"{cache_file.stat().st_size / 1024:.1f} KB"
            }
            cached_symbols.append(symbol_info)
        except Exception as e:
            print(f"Error reading cache file {cache_file}: {e}")
    
    return cached_symbols

# # Example usage and testing
# if __name__ == "__main__":
#     # Example 1: Basic usage
#     print("=== Example 1: Basic Usage ===")
#     data1 = downloader("AAPL", "2023-01-01", "2023-12-31")
#     print(f"Downloaded {len(data1)} records for AAPL")
    
#     # Example 2: Second call should use cache
#     print("\n=== Example 2: Cache Usage ===")
#     data2 = downloader("AAPL", "2023-06-01", "2023-08-31")  # Should use cache
#     print(f"Retrieved {len(data2)} records for AAPL (from cache)")
    
#     # Example 3: Extending date range
#     print("\n=== Example 3: Extending Range ===")
#     data3 = downloader("AAPL", "2022-01-01", "2024-01-31")  # Should fetch missing parts
#     print(f"Retrieved {len(data3)} records for AAPL (extended range)")
    
#     # Example 4: List cached data
#     print("\n=== Example 4: Cache Info ===")
#     cached = list_cached_symbols()
#     for info in cached:
#         print(f"Symbol: {info['symbol']}")
#         print(f"  Date Range: {info['date_range']}")
#         print(f"  Records: {info['records']}")
#         print(f"  Last Updated: {info['last_update']}")
#         print(f"  File Size: {info['file_size']}")

# %%
tech=['AAPL','PYPL','GOOGL','QCOM','MTCH']
petrochem=['DOW','XOM','OXY','CVX','SLB','SU']
retail=['TGT','UPS','NKE']
pharma=['AZN','PFE','MRK','BMY','JNJ','TMO']
insurance=['UNH','HUM']
metal=['VALE','RIO']
zhong=['JD']
food=['KHC','GIS','PEP','DEO','MDLZ','BF-B']
hype=['TSLA','AVGO']
bill=['TLT','IEF']
diverse=['DAL','NEE','VZ','CCL']
symbols = tech + petrochem + retail + pharma + metal + zhong + hype + bill+diverse+insurance+food
uk_symbols=[k+'.L' for k in ['UTG','DOM','GLEN','DGE','POLR','IPX','WPP','SAFE']]

# %%
start_date = '2007-01-03'

today = datetime.now()

end_date = (today - timedelta(days=3)).strftime('%Y-%m-%d')
n_days=252*10

# %%
all_price=dict()
for stock in symbols:
    data =  downloader(stock, start_date,end_date)
    all_price[stock]=data
combined_df=_organise_price_data(all_price, n_days)
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['PYPL']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-03 -> 2015-07-05) (Yahoo error = "Data doesn\'t exist for startDate = 1167800400, endDate = 1436068800")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-03 -> 2019-03-19) (Yahoo error = "Data doesn\'t exist for startDate = 1167800400, endDate = 1552968000")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['JD']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-03 -> 2014-05-21) (Yahoo error = "Data doesn\'t exist for startDate = 1167800400, endDate = 1400644800")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['TSLA']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-03 -> 2010-06-28) (Yahoo error = "Data doesn\'t exist for startDate = 1167800400, endDate = 1277697600")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AVGO']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-03 -> 2009-08-05) (Yahoo error = "Data doesn\'t exist for startDate = 1167800400, endDate = 1249444800")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DAL']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-03 -> 2007-05-02) (Yahoo error = "Data doesn\'t exist for startDate = 1167800400, endDate = 1178078400")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KHC']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-03 -> 2015-07-05) (Yahoo error = "Data doesn\'t exist for startDate = 1167800400, endDate = 1436068800")')
# Processing data request for AAPL from 2007-01-03 to 2025-06-24...
# Found cached data for AAPL (last updated: 2025-06-27 18:12:16)
# All requested data for AAPL available in cache!
# Processing data request for PYPL from 2007-01-03 to 2025-06-24...
# Found cached data for PYPL (last updated: 2025-06-27 18:23:22)
# Fetching missing data for PYPL: 2007-01-03 to 2015-07-05
# Data download complete for PYPL. Shape: (2508, 5)
# Processing data request for GOOGL from 2007-01-03 to 2025-06-24...
# Found cached data for GOOGL (last updated: 2025-06-27 18:12:17)
# All requested data for GOOGL available in cache!
# Processing data request for QCOM from 2007-01-03 to 2025-06-24...
# Found cached data for QCOM (last updated: 2025-06-27 18:12:28)
# All requested data for QCOM available in cache!
# Processing data request for MTCH from 2007-01-03 to 2025-06-24...
# Found cached data for MTCH (last updated: 2025-06-27 18:12:10)
# All requested data for MTCH available in cache!
# Processing data request for DOW from 2007-01-03 to 2025-06-24...
# Found cached data for DOW (last updated: 2025-06-27 18:23:23)
# Fetching missing data for DOW: 2007-01-03 to 2019-03-19
# Data download complete for DOW. Shape: (1575, 5)
# Processing data request for XOM from 2007-01-03 to 2025-06-24...
# Found cached data for XOM (last updated: 2025-06-27 18:12:22)
# All requested data for XOM available in cache!
# Processing data request for OXY from 2007-01-03 to 2025-06-24...
# Found cached data for OXY (last updated: 2025-06-27 18:12:11)
# All requested data for OXY available in cache!
# Processing data request for CVX from 2007-01-03 to 2025-06-24...
# Found cached data for CVX (last updated: 2025-06-27 18:12:29)
# All requested data for CVX available in cache!
# Processing data request for SLB from 2007-01-03 to 2025-06-24...
# Found cached data for SLB (last updated: 2025-06-27 18:12:11)
# All requested data for SLB available in cache!
# Processing data request for SU from 2007-01-03 to 2025-06-24...
# Found cached data for SU (last updated: 2025-06-27 18:12:11)
# All requested data for SU available in cache!
# Processing data request for TGT from 2007-01-03 to 2025-06-24...
# Found cached data for TGT (last updated: 2025-06-27 18:12:30)
# All requested data for TGT available in cache!
# Processing data request for UPS from 2007-01-03 to 2025-06-24...
# Found cached data for UPS (last updated: 2025-06-27 18:12:32)
# All requested data for UPS available in cache!
# Processing data request for NKE from 2007-01-03 to 2025-06-24...
# Found cached data for NKE (last updated: 2025-06-27 18:12:18)
# All requested data for NKE available in cache!
# Processing data request for AZN from 2007-01-03 to 2025-06-24...
# Found cached data for AZN (last updated: 2025-06-27 18:12:12)
# All requested data for AZN available in cache!
# Processing data request for PFE from 2007-01-03 to 2025-06-24...
# Found cached data for PFE (last updated: 2025-06-27 18:12:12)
# All requested data for PFE available in cache!
# Processing data request for MRK from 2007-01-03 to 2025-06-24...
# Found cached data for MRK (last updated: 2025-06-27 18:12:32)
# All requested data for MRK available in cache!
# Processing data request for BMY from 2007-01-03 to 2025-06-24...
# Found cached data for BMY (last updated: 2025-06-27 18:12:12)
# All requested data for BMY available in cache!
# Processing data request for JNJ from 2007-01-03 to 2025-06-24...
# Found cached data for JNJ (last updated: 2025-06-27 18:12:13)
# All requested data for JNJ available in cache!
# Processing data request for TMO from 2007-01-03 to 2025-06-24...
# Found cached data for TMO (last updated: 2025-06-27 18:12:22)
# All requested data for TMO available in cache!
# Processing data request for VALE from 2007-01-03 to 2025-06-24...
# Found cached data for VALE (last updated: 2025-06-27 18:12:13)
# All requested data for VALE available in cache!
# Processing data request for RIO from 2007-01-03 to 2025-06-24...
# Found cached data for RIO (last updated: 2025-06-27 18:12:13)
# All requested data for RIO available in cache!
# Processing data request for JD from 2007-01-03 to 2025-06-24...
# Found cached data for JD (last updated: 2025-06-27 18:23:23)
# Fetching missing data for JD: 2007-01-03 to 2014-05-21
# Data download complete for JD. Shape: (2789, 5)
# Processing data request for TSLA from 2007-01-03 to 2025-06-24...
# Found cached data for TSLA (last updated: 2025-06-27 18:23:23)
# Fetching missing data for TSLA: 2007-01-03 to 2010-06-28
# Data download complete for TSLA. Shape: (3770, 5)
# Processing data request for AVGO from 2007-01-03 to 2025-06-24...
# Found cached data for AVGO (last updated: 2025-06-27 18:23:23)
# Fetching missing data for AVGO: 2007-01-03 to 2009-08-05
# Data download complete for AVGO. Shape: (3995, 5)
# Processing data request for TLT from 2007-01-03 to 2025-06-24...
# Found cached data for TLT (last updated: 2025-06-27 18:12:14)
# All requested data for TLT available in cache!
# Processing data request for IEF from 2007-01-03 to 2025-06-24...
# Found cached data for IEF (last updated: 2025-06-27 18:12:14)
# All requested data for IEF available in cache!
# Processing data request for DAL from 2007-01-03 to 2025-06-24...
# Found cached data for DAL (last updated: 2025-06-27 18:23:23)
# Fetching missing data for DAL: 2007-01-03 to 2007-05-02
# Data download complete for DAL. Shape: (4565, 5)
# Processing data request for NEE from 2007-01-03 to 2025-06-24...
# Found cached data for NEE (last updated: 2025-06-27 18:12:12)
# All requested data for NEE available in cache!
# Processing data request for VZ from 2007-01-03 to 2025-06-24...
# Found cached data for VZ (last updated: 2025-06-27 18:08:16)
# All requested data for VZ available in cache!
# Processing data request for CCL from 2007-01-03 to 2025-06-24...
# Found cached data for CCL (last updated: 2025-06-27 18:12:14)
# All requested data for CCL available in cache!
# Processing data request for UNH from 2007-01-03 to 2025-06-24...
# Found cached data for UNH (last updated: 2025-06-27 18:12:17)
# All requested data for UNH available in cache!
# Processing data request for HUM from 2007-01-03 to 2025-06-24...
# Found cached data for HUM (last updated: 2025-06-27 18:12:32)
# All requested data for HUM available in cache!
# Processing data request for KHC from 2007-01-03 to 2025-06-24...
# Found cached data for KHC (last updated: 2025-06-27 18:23:23)
# Fetching missing data for KHC: 2007-01-03 to 2015-07-05
# Data download complete for KHC. Shape: (2508, 5)
# Processing data request for GIS from 2007-01-03 to 2025-06-24...
# Found cached data for GIS (last updated: 2025-06-27 18:12:15)
# All requested data for GIS available in cache!
# Processing data request for PEP from 2007-01-03 to 2025-06-24...
# Found cached data for PEP (last updated: 2025-06-27 18:12:21)
# All requested data for PEP available in cache!
# Processing data request for DEO from 2007-01-03 to 2025-06-24...
# Found cached data for DEO (last updated: 2025-06-27 18:12:15)
# All requested data for DEO available in cache!
# Processing data request for MDLZ from 2007-01-03 to 2025-06-24...
# Found cached data for MDLZ (last updated: 2025-06-27 18:23:24)
# All requested data for MDLZ available in cache!
# Processing data request for BF-B from 2007-01-03 to 2025-06-24...
# Found cached data for BF-B (last updated: 2025-06-27 18:12:15)
# All requested data for BF-B available in cache!

# %%
active_options_stocks=pd.read_csv('../data/active_options_stocks/active_stock_options.csv',keep_default_na=False)
active_options_stocks.set_index('Ticker',inplace=True)

# %%
transf=lambda k:log_change(k)
cor_days=252*1

active_stocks_corr=dict()
active_etf_corr=dict()
# for stock in active_options_etf.index:
#     data =  downloader(stock, start_date,end_date)
#     print('start')
        
#     temp=combined_df.corrwith(data[('Close',stock)], axis=0)
#     #temp=calculate_series_stock_correlations(test_dic,data,252,reference_symbol=stock)
#     print('done')
#     active_etf_corr[stock]=temp
for stock in active_options_stocks.index:
    data =  downloader(stock, (today - timedelta(days=cor_days)).strftime('%Y-%m-%d'),end_date)
    #print('start')
        
    temp=transf(combined_df).corrwith(transf(data[('Close',stock)]), axis=0)
    #temp=calculate_series_stock_correlations(test_dic,data,252,reference_symbol=stock)
    #print('done')
    active_stocks_corr[stock]=temp
    #all_price_active_stocks[stock]=data
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CRCL']: YFPricesMissingError('possibly delisted; no price data found  (1d 2024-10-18 -> 2025-06-03) (Yahoo error = "Data doesn\'t exist for startDate = 1729224000, endDate = 1748923200")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CRWV']: YFPricesMissingError('possibly delisted; no price data found  (1d 2024-10-18 -> 2025-03-27) (Yahoo error = "Data doesn\'t exist for startDate = 1729224000, endDate = 1743048000")')
# Processing data request for TSLA from 2024-10-18 to 2025-06-24...
# Found cached data for TSLA (last updated: 2025-06-27 18:12:16)
# All requested data for TSLA available in cache!
# Processing data request for NVDA from 2024-10-18 to 2025-06-24...
# Found cached data for NVDA (last updated: 2025-06-27 18:12:16)
# All requested data for NVDA available in cache!
# Processing data request for META from 2024-10-18 to 2025-06-24...
# Found cached data for META (last updated: 2025-06-27 18:12:16)
# All requested data for META available in cache!
# Processing data request for COIN from 2024-10-18 to 2025-06-24...
# Found cached data for COIN (last updated: 2025-06-27 18:12:16)
# All requested data for COIN available in cache!
# Processing data request for AAPL from 2024-10-18 to 2025-06-24...
# Found cached data for AAPL (last updated: 2025-06-27 18:12:16)
# All requested data for AAPL available in cache!
# Processing data request for NFLX from 2024-10-18 to 2025-06-24...
# Found cached data for NFLX (last updated: 2025-06-27 18:12:16)
# All requested data for NFLX available in cache!
# Processing data request for MSFT from 2024-10-18 to 2025-06-24...
# Found cached data for MSFT (last updated: 2025-06-27 18:12:16)
# All requested data for MSFT available in cache!
# Processing data request for AMZN from 2024-10-18 to 2025-06-24...
# Found cached data for AMZN (last updated: 2025-06-27 18:12:16)
# All requested data for AMZN available in cache!
# Processing data request for MSTR from 2024-10-18 to 2025-06-24...
# Found cached data for MSTR (last updated: 2025-06-27 18:12:16)
# All requested data for MSTR available in cache!
# Processing data request for AMD from 2024-10-18 to 2025-06-24...
# Found cached data for AMD (last updated: 2025-06-27 18:12:16)
# All requested data for AMD available in cache!
# Processing data request for PLTR from 2024-10-18 to 2025-06-24...
# Found cached data for PLTR (last updated: 2025-06-27 18:12:17)
# All requested data for PLTR available in cache!
# Processing data request for CRCL from 2024-10-18 to 2025-06-24...
# Found cached data for CRCL (last updated: 2025-06-27 18:14:06)
# Fetching missing data for CRCL: 2024-10-18 to 2025-06-03
# Data download complete for CRCL. Shape: (14, 5)
# Processing data request for MU from 2024-10-18 to 2025-06-24...
# Found cached data for MU (last updated: 2025-06-27 18:12:17)
# All requested data for MU available in cache!
# Processing data request for UNH from 2024-10-18 to 2025-06-24...
# Found cached data for UNH (last updated: 2025-06-27 18:12:17)
# All requested data for UNH available in cache!
# Processing data request for GOOGL from 2024-10-18 to 2025-06-24...
# Found cached data for GOOGL (last updated: 2025-06-27 18:12:17)
# All requested data for GOOGL available in cache!
# Processing data request for AVGO from 2024-10-18 to 2025-06-24...
# Found cached data for AVGO (last updated: 2025-06-27 18:12:17)
# All requested data for AVGO available in cache!
# Processing data request for CRWV from 2024-10-18 to 2025-06-24...
# Found cached data for CRWV (last updated: 2025-06-27 18:14:07)
# Fetching missing data for CRWV: 2024-10-18 to 2025-03-27
# Data download complete for CRWV. Shape: (60, 5)
# Processing data request for GS from 2024-10-18 to 2025-06-24...
# Found cached data for GS (last updated: 2025-06-27 18:12:17)
# All requested data for GS available in cache!
# Processing data request for SMCI from 2024-10-18 to 2025-06-24...
# Found cached data for SMCI (last updated: 2025-06-27 18:12:18)
# All requested data for SMCI available in cache!
# Processing data request for JPM from 2024-10-18 to 2025-06-24...
# Found cached data for JPM (last updated: 2025-06-27 18:12:18)
# All requested data for JPM available in cache!
# Processing data request for COST from 2024-10-18 to 2025-06-24...
# Found cached data for COST (last updated: 2025-06-27 18:12:18)
# All requested data for COST available in cache!
# Processing data request for GOOG from 2024-10-18 to 2025-06-24...
# Found cached data for GOOG (last updated: 2025-06-27 18:12:18)
# All requested data for GOOG available in cache!
# Processing data request for NKE from 2024-10-18 to 2025-06-24...
# Found cached data for NKE (last updated: 2025-06-27 18:12:18)
# All requested data for NKE available in cache!
# Processing data request for CRWD from 2024-10-18 to 2025-06-24...
# Found cached data for CRWD (last updated: 2025-06-27 18:12:18)
# All requested data for CRWD available in cache!
# Processing data request for CVNA from 2024-10-18 to 2025-06-24...
# Found cached data for CVNA (last updated: 2025-06-27 18:12:18)
# All requested data for CVNA available in cache!
# Processing data request for C from 2024-10-18 to 2025-06-24...
# Found cached data for C (last updated: 2025-06-27 18:12:18)
# All requested data for C available in cache!
# Processing data request for HOOD from 2024-10-18 to 2025-06-24...
# Found cached data for HOOD (last updated: 2025-06-27 18:12:18)
# All requested data for HOOD available in cache!
# Processing data request for LLY from 2024-10-18 to 2025-06-24...
# Found cached data for LLY (last updated: 2025-06-27 18:12:18)
# All requested data for LLY available in cache!
# Processing data request for BA from 2024-10-18 to 2025-06-24...
# Found cached data for BA (last updated: 2025-06-27 18:12:19)
# All requested data for BA available in cache!
# Processing data request for TSM from 2024-10-18 to 2025-06-24...
# Found cached data for TSM (last updated: 2025-06-27 18:12:19)
# All requested data for TSM available in cache!
# Processing data request for MRVL from 2024-10-18 to 2025-06-24...
# Found cached data for MRVL (last updated: 2025-06-27 18:12:19)
# All requested data for MRVL available in cache!
# Processing data request for BRK-B from 2024-10-18 to 2025-06-24...
# Found cached data for BRK-B (last updated: 2025-06-27 18:12:19)
# All requested data for BRK-B available in cache!
# Processing data request for HIMS from 2024-10-18 to 2025-06-24...
# Found cached data for HIMS (last updated: 2025-06-27 18:12:19)
# All requested data for HIMS available in cache!
# Processing data request for SPOT from 2024-10-18 to 2025-06-24...
# Found cached data for SPOT (last updated: 2025-06-27 18:12:19)
# All requested data for SPOT available in cache!
# Processing data request for ORCL from 2024-10-18 to 2025-06-24...
# Found cached data for ORCL (last updated: 2025-06-27 18:12:19)
# All requested data for ORCL available in cache!
# Processing data request for UBER from 2024-10-18 to 2025-06-24...
# Found cached data for UBER (last updated: 2025-06-27 18:12:19)
# All requested data for UBER available in cache!
# Processing data request for APP from 2024-10-18 to 2025-06-24...
# Found cached data for APP (last updated: 2025-06-27 18:12:19)
# All requested data for APP available in cache!
# Processing data request for ADBE from 2024-10-18 to 2025-06-24...
# Found cached data for ADBE (last updated: 2025-06-27 18:12:20)
# All requested data for ADBE available in cache!
# Processing data request for ASML from 2024-10-18 to 2025-06-24...
# Found cached data for ASML (last updated: 2025-06-27 18:12:20)
# All requested data for ASML available in cache!
# Processing data request for V from 2024-10-18 to 2025-06-24...
# Found cached data for V (last updated: 2025-06-27 18:12:20)
# All requested data for V available in cache!
# Processing data request for MCD from 2024-10-18 to 2025-06-24...
# Found cached data for MCD (last updated: 2025-06-27 18:12:20)
# All requested data for MCD available in cache!
# Processing data request for GE from 2024-10-18 to 2025-06-24...
# Found cached data for GE (last updated: 2025-06-27 18:12:20)
# All requested data for GE available in cache!
# Processing data request for SNOW from 2024-10-18 to 2025-06-24...
# Found cached data for SNOW (last updated: 2025-06-27 18:12:20)
# All requested data for SNOW available in cache!
# Processing data request for BABA from 2024-10-18 to 2025-06-24...
# Found cached data for BABA (last updated: 2025-06-27 18:12:20)
# All requested data for BABA available in cache!
# Processing data request for WFC from 2024-10-18 to 2025-06-24...
# Found cached data for WFC (last updated: 2025-06-27 18:12:20)
# All requested data for WFC available in cache!
# Processing data request for FDX from 2024-10-18 to 2025-06-24...
# Found cached data for FDX (last updated: 2025-06-27 18:12:21)
# All requested data for FDX available in cache!
# Processing data request for PEP from 2024-10-18 to 2025-06-24...
# Found cached data for PEP (last updated: 2025-06-27 18:12:21)
# All requested data for PEP available in cache!
# Processing data request for CAT from 2024-10-18 to 2025-06-24...
# Found cached data for CAT (last updated: 2025-06-27 18:12:21)
# All requested data for CAT available in cache!
# Processing data request for LULU from 2024-10-18 to 2025-06-24...
# Found cached data for LULU (last updated: 2025-06-27 18:12:21)
# All requested data for LULU available in cache!
# Processing data request for DIS from 2024-10-18 to 2025-06-24...
# Found cached data for DIS (last updated: 2025-06-27 18:12:21)
# All requested data for DIS available in cache!
# Processing data request for WMT from 2024-10-18 to 2025-06-24...
# Found cached data for WMT (last updated: 2025-06-27 18:12:21)
# All requested data for WMT available in cache!
# Processing data request for BAC from 2024-10-18 to 2025-06-24...
# Found cached data for BAC (last updated: 2025-06-27 18:12:21)
# All requested data for BAC available in cache!
# Processing data request for FSLR from 2024-10-18 to 2025-06-24...
# Found cached data for FSLR (last updated: 2025-06-27 18:12:22)
# All requested data for FSLR available in cache!
# Processing data request for RKLB from 2024-10-18 to 2025-06-24...
# Found cached data for RKLB (last updated: 2025-06-27 18:12:22)
# All requested data for RKLB available in cache!
# Processing data request for TMO from 2024-10-18 to 2025-06-24...
# Found cached data for TMO (last updated: 2025-06-27 18:12:22)
# All requested data for TMO available in cache!
# Processing data request for DELL from 2024-10-18 to 2025-06-24...
# Found cached data for DELL (last updated: 2025-06-27 18:12:22)
# All requested data for DELL available in cache!
# Processing data request for MS from 2024-10-18 to 2025-06-24...
# Found cached data for MS (last updated: 2025-06-27 18:12:22)
# All requested data for MS available in cache!
# Processing data request for CRM from 2024-10-18 to 2025-06-24...
# Found cached data for CRM (last updated: 2025-06-27 18:12:22)
# All requested data for CRM available in cache!
# Processing data request for ARM from 2024-10-18 to 2025-06-24...
# Found cached data for ARM (last updated: 2025-06-27 18:12:22)
# All requested data for ARM available in cache!
# Processing data request for XOM from 2024-10-18 to 2025-06-24...
# Found cached data for XOM (last updated: 2025-06-27 18:12:22)
# All requested data for XOM available in cache!
# Processing data request for NOW from 2024-10-18 to 2025-06-24...
# Found cached data for NOW (last updated: 2025-06-27 18:12:22)
# All requested data for NOW available in cache!
# Processing data request for SOFI from 2024-10-18 to 2025-06-24...
# Found cached data for SOFI (last updated: 2025-06-27 18:12:25)
# All requested data for SOFI available in cache!
# Processing data request for RDDT from 2024-10-18 to 2025-06-24...
# Found cached data for RDDT (last updated: 2025-06-27 18:12:25)
# All requested data for RDDT available in cache!
# Processing data request for KVUE from 2024-10-18 to 2025-06-24...
# Found cached data for KVUE (last updated: 2025-06-27 18:12:25)
# All requested data for KVUE available in cache!
# Processing data request for MA from 2024-10-18 to 2025-06-24...
# Found cached data for MA (last updated: 2025-06-27 18:12:26)
# All requested data for MA available in cache!
# Processing data request for ANET from 2024-10-18 to 2025-06-24...
# Found cached data for ANET (last updated: 2025-06-27 18:12:26)
# All requested data for ANET available in cache!
# Processing data request for SHOP from 2024-10-18 to 2025-06-24...
# Found cached data for SHOP (last updated: 2025-06-27 18:12:26)
# All requested data for SHOP available in cache!
# Processing data request for PYPL from 2024-10-18 to 2025-06-24...
# Found cached data for PYPL (last updated: 2025-06-27 18:12:26)
# All requested data for PYPL available in cache!
# Processing data request for CAR from 2024-10-18 to 2025-06-24...
# Found cached data for CAR (last updated: 2025-06-27 18:12:26)
# All requested data for CAR available in cache!
# Processing data request for PANW from 2024-10-18 to 2025-06-24...
# Found cached data for PANW (last updated: 2025-06-27 18:12:26)
# All requested data for PANW available in cache!
# Processing data request for BTI from 2024-10-18 to 2025-06-24...
# Found cached data for BTI (last updated: 2025-06-27 18:12:26)
# All requested data for BTI available in cache!
# Processing data request for LMT from 2024-10-18 to 2025-06-24...
# Found cached data for LMT (last updated: 2025-06-27 18:12:26)
# All requested data for LMT available in cache!
# Processing data request for INTC from 2024-10-18 to 2025-06-24...
# Found cached data for INTC (last updated: 2025-06-27 18:12:27)
# All requested data for INTC available in cache!
# Processing data request for ENPH from 2024-10-18 to 2025-06-24...
# Found cached data for ENPH (last updated: 2025-06-27 18:12:27)
# All requested data for ENPH available in cache!
# Processing data request for FCX from 2024-10-18 to 2025-06-24...
# Found cached data for FCX (last updated: 2025-06-27 18:12:27)
# All requested data for FCX available in cache!
# Processing data request for CSCO from 2024-10-18 to 2025-06-24...
# Found cached data for CSCO (last updated: 2025-06-27 18:12:27)
# All requested data for CSCO available in cache!
# Processing data request for HD from 2024-10-18 to 2025-06-24...
# Found cached data for HD (last updated: 2025-06-27 18:12:27)
# All requested data for HD available in cache!
# Processing data request for TTD from 2024-10-18 to 2025-06-24...
# Found cached data for TTD (last updated: 2025-06-27 18:12:27)
# All requested data for TTD available in cache!
# Processing data request for PG from 2024-10-18 to 2025-06-24...
# Found cached data for PG (last updated: 2025-06-27 18:12:27)
# All requested data for PG available in cache!
# Processing data request for IBM from 2024-10-18 to 2025-06-24...
# Found cached data for IBM (last updated: 2025-06-27 18:12:28)
# All requested data for IBM available in cache!
# Processing data request for ASTS from 2024-10-18 to 2025-06-24...
# Found cached data for ASTS (last updated: 2025-06-27 18:12:28)
# All requested data for ASTS available in cache!
# Processing data request for CCJ from 2024-10-18 to 2025-06-24...
# Found cached data for CCJ (last updated: 2025-06-27 18:12:28)
# All requested data for CCJ available in cache!
# Processing data request for VST from 2024-10-18 to 2025-06-24...
# Found cached data for VST (last updated: 2025-06-27 18:12:28)
# All requested data for VST available in cache!
# Processing data request for AXP from 2024-10-18 to 2025-06-24...
# Found cached data for AXP (last updated: 2025-06-27 18:12:28)
# All requested data for AXP available in cache!
# Processing data request for VRT from 2024-10-18 to 2025-06-24...
# Found cached data for VRT (last updated: 2025-06-27 18:12:28)
# All requested data for VRT available in cache!
# Processing data request for QCOM from 2024-10-18 to 2025-06-24...
# Found cached data for QCOM (last updated: 2025-06-27 18:12:28)
# All requested data for QCOM available in cache!
# Processing data request for CMG from 2024-10-18 to 2025-06-24...
# Found cached data for CMG (last updated: 2025-06-27 18:12:29)
# All requested data for CMG available in cache!
# Processing data request for GME from 2024-10-18 to 2025-06-24...
# Found cached data for GME (last updated: 2025-06-27 18:12:29)
# All requested data for GME available in cache!
# Processing data request for CVX from 2024-10-18 to 2025-06-24...
# Found cached data for CVX (last updated: 2025-06-27 18:12:29)
# All requested data for CVX available in cache!
# Processing data request for MRNA from 2024-10-18 to 2025-06-24...
# Found cached data for MRNA (last updated: 2025-06-27 18:12:29)
# All requested data for MRNA available in cache!
# Processing data request for IREN from 2024-10-18 to 2025-06-24...
# Found cached data for IREN (last updated: 2025-06-27 18:12:29)
# All requested data for IREN available in cache!
# Processing data request for AVAV from 2024-10-18 to 2025-06-24...
# Found cached data for AVAV (last updated: 2025-06-27 18:12:29)
# All requested data for AVAV available in cache!
# Processing data request for RBLX from 2024-10-18 to 2025-06-24...
# Found cached data for RBLX (last updated: 2025-06-27 18:12:29)
# All requested data for RBLX available in cache!
# Processing data request for GEV from 2024-10-18 to 2025-06-24...
# Found cached data for GEV (last updated: 2025-06-27 18:12:29)
# All requested data for GEV available in cache!
# Processing data request for AMAT from 2024-10-18 to 2025-06-24...
# Found cached data for AMAT (last updated: 2025-06-27 18:12:29)
# All requested data for AMAT available in cache!
# Processing data request for RCL from 2024-10-18 to 2025-06-24...
# Found cached data for RCL (last updated: 2025-06-27 18:12:29)
# All requested data for RCL available in cache!
# Processing data request for CELH from 2024-10-18 to 2025-06-24...
# Found cached data for CELH (last updated: 2025-06-27 18:12:29)
# All requested data for CELH available in cache!
# Processing data request for ROST from 2024-10-18 to 2025-06-24...
# Found cached data for ROST (last updated: 2025-06-27 18:12:30)
# All requested data for ROST available in cache!
# Processing data request for QS from 2024-10-18 to 2025-06-24...
# Found cached data for QS (last updated: 2025-06-27 18:12:30)
# All requested data for QS available in cache!
# Processing data request for PDD from 2024-10-18 to 2025-06-24...
# Found cached data for PDD (last updated: 2025-06-27 18:12:30)
# All requested data for PDD available in cache!
# Processing data request for ALAB from 2024-10-18 to 2025-06-24...
# Found cached data for ALAB (last updated: 2025-06-27 18:12:30)
# All requested data for ALAB available in cache!
# Processing data request for TGT from 2024-10-18 to 2025-06-24...
# Found cached data for TGT (last updated: 2025-06-27 18:12:30)
# All requested data for TGT available in cache!
# Processing data request for KKR from 2024-10-18 to 2025-06-24...
# Found cached data for KKR (last updated: 2025-06-27 18:12:30)
# All requested data for KKR available in cache!
# Processing data request for ABNB from 2024-10-18 to 2025-06-24...
# Found cached data for ABNB (last updated: 2025-06-27 18:12:30)
# All requested data for ABNB available in cache!
# Processing data request for ZS from 2024-10-18 to 2025-06-24...
# Found cached data for ZS (last updated: 2025-06-27 18:12:30)
# All requested data for ZS available in cache!
# Processing data request for IONQ from 2024-10-18 to 2025-06-24...
# Found cached data for IONQ (last updated: 2025-06-27 18:12:30)
# All requested data for IONQ available in cache!
# Processing data request for EQIX from 2024-10-18 to 2025-06-24...
# Found cached data for EQIX (last updated: 2025-06-27 18:12:31)
# All requested data for EQIX available in cache!
# Processing data request for TEM from 2024-10-18 to 2025-06-24...
# Found cached data for TEM (last updated: 2025-06-27 18:12:31)
# All requested data for TEM available in cache!
# Processing data request for OSCR from 2024-10-18 to 2025-06-24...
# Found cached data for OSCR (last updated: 2025-06-27 18:12:31)
# All requested data for OSCR available in cache!
# Processing data request for MARA from 2024-10-18 to 2025-06-24...
# Found cached data for MARA (last updated: 2025-06-27 18:12:31)
# All requested data for MARA available in cache!
# Processing data request for ISRG from 2024-10-18 to 2025-06-24...
# Found cached data for ISRG (last updated: 2025-06-27 18:12:31)
# All requested data for ISRG available in cache!
# Processing data request for GILD from 2024-10-18 to 2025-06-24...
# Found cached data for GILD (last updated: 2025-06-27 18:12:31)
# All requested data for GILD available in cache!
# Processing data request for RH from 2024-10-18 to 2025-06-24...
# Found cached data for RH (last updated: 2025-06-27 18:12:31)
# All requested data for RH available in cache!
# Processing data request for CEG from 2024-10-18 to 2025-06-24...
# Found cached data for CEG (last updated: 2025-06-27 18:12:31)
# All requested data for CEG available in cache!
# Processing data request for CVS from 2024-10-18 to 2025-06-24...
# Found cached data for CVS (last updated: 2025-06-27 18:12:31)
# All requested data for CVS available in cache!
# Processing data request for AI from 2024-10-18 to 2025-06-24...
# Found cached data for AI (last updated: 2025-06-27 18:12:31)
# All requested data for AI available in cache!
# Processing data request for COF from 2024-10-18 to 2025-06-24...
# Found cached data for COF (last updated: 2025-06-27 18:12:32)
# All requested data for COF available in cache!
# Processing data request for ETSY from 2024-10-18 to 2025-06-24...
# Found cached data for ETSY (last updated: 2025-06-27 18:12:32)
# All requested data for ETSY available in cache!
# Processing data request for MRK from 2024-10-18 to 2025-06-24...
# Found cached data for MRK (last updated: 2025-06-27 18:12:32)
# All requested data for MRK available in cache!
# Processing data request for UPS from 2024-10-18 to 2025-06-24...
# Found cached data for UPS (last updated: 2025-06-27 18:12:32)
# All requested data for UPS available in cache!
# Processing data request for PM from 2024-10-18 to 2025-06-24...
# Found cached data for PM (last updated: 2025-06-27 18:12:32)
# All requested data for PM available in cache!
# Processing data request for DDOG from 2024-10-18 to 2025-06-24...
# Found cached data for DDOG (last updated: 2025-06-27 18:12:32)
# All requested data for DDOG available in cache!
# Processing data request for HUM from 2024-10-18 to 2025-06-24...
# Found cached data for HUM (last updated: 2025-06-27 18:12:32)
# All requested data for HUM available in cache!
# Processing data request for CAVA from 2024-10-18 to 2025-06-24...
# Found cached data for CAVA (last updated: 2025-06-27 18:12:32)
# All requested data for CAVA available in cache!
# Processing data request for NVO from 2024-10-18 to 2025-06-24...
# Found cached data for NVO (last updated: 2025-06-27 18:08:12)
# All requested data for NVO available in cache!
# Processing data request for KO from 2024-10-18 to 2025-06-24...
# Found cached data for KO (last updated: 2025-06-27 18:08:12)
# All requested data for KO available in cache!
# Processing data request for RIOT from 2024-10-18 to 2025-06-24...
# Found cached data for RIOT (last updated: 2025-06-27 18:08:12)
# All requested data for RIOT available in cache!
# Processing data request for JNJ from 2024-10-18 to 2025-06-24...
# Found cached data for JNJ (last updated: 2025-06-27 18:12:13)
# All requested data for JNJ available in cache!
# Processing data request for LOW from 2024-10-18 to 2025-06-24...
# Found cached data for LOW (last updated: 2025-06-27 18:08:13)
# All requested data for LOW available in cache!
# Processing data request for MDT from 2024-10-18 to 2025-06-24...
# Found cached data for MDT (last updated: 2025-06-27 18:08:13)
# All requested data for MDT available in cache!
# Processing data request for CLX from 2024-10-18 to 2025-06-24...
# Found cached data for CLX (last updated: 2025-06-27 18:08:13)
# All requested data for CLX available in cache!
# Processing data request for GM from 2024-10-18 to 2025-06-24...
# Found cached data for GM (last updated: 2025-06-27 18:08:13)
# All requested data for GM available in cache!
# Processing data request for OKTA from 2024-10-18 to 2025-06-24...
# Found cached data for OKTA (last updated: 2025-06-27 18:08:13)
# All requested data for OKTA available in cache!
# Processing data request for DASH from 2024-10-18 to 2025-06-24...
# Found cached data for DASH (last updated: 2025-06-27 18:08:13)
# All requested data for DASH available in cache!
# Processing data request for WDAY from 2024-10-18 to 2025-06-24...
# Found cached data for WDAY (last updated: 2025-06-27 18:08:13)
# All requested data for WDAY available in cache!
# Processing data request for PCG from 2024-10-18 to 2025-06-24...
# Found cached data for PCG (last updated: 2025-06-27 18:08:14)
# All requested data for PCG available in cache!
# Processing data request for ROKU from 2024-10-18 to 2025-06-24...
# Found cached data for ROKU (last updated: 2025-06-27 18:08:14)
# All requested data for ROKU available in cache!
# Processing data request for DKS from 2024-10-18 to 2025-06-24...
# Found cached data for DKS (last updated: 2025-06-27 18:08:14)
# All requested data for DKS available in cache!
# Processing data request for LRCX from 2024-10-18 to 2025-06-24...
# Found cached data for LRCX (last updated: 2025-06-27 18:08:14)
# All requested data for LRCX available in cache!
# Processing data request for FUTU from 2024-10-18 to 2025-06-24...
# Found cached data for FUTU (last updated: 2025-06-27 18:08:14)
# All requested data for FUTU available in cache!
# Processing data request for BX from 2024-10-18 to 2025-06-24...
# Found cached data for BX (last updated: 2025-06-27 18:08:15)
# All requested data for BX available in cache!
# Processing data request for TXN from 2024-10-18 to 2025-06-24...
# Found cached data for TXN (last updated: 2025-06-27 18:08:15)
# All requested data for TXN available in cache!
# Processing data request for SBUX from 2024-10-18 to 2025-06-24...
# Found cached data for SBUX (last updated: 2025-06-27 18:08:15)
# All requested data for SBUX available in cache!
# Processing data request for ABBV from 2024-10-18 to 2025-06-24...
# Found cached data for ABBV (last updated: 2025-06-27 18:08:15)
# All requested data for ABBV available in cache!
# Processing data request for RTX from 2024-10-18 to 2025-06-24...
# Found cached data for RTX (last updated: 2025-06-27 18:08:15)
# All requested data for RTX available in cache!
# Processing data request for AMGN from 2024-10-18 to 2025-06-24...
# Found cached data for AMGN (last updated: 2025-06-27 18:08:15)
# All requested data for AMGN available in cache!
# Processing data request for U from 2024-10-18 to 2025-06-24...
# Found cached data for U (last updated: 2025-06-27 18:08:15)
# All requested data for U available in cache!
# Processing data request for BIDU from 2024-10-18 to 2025-06-24...
# Found cached data for BIDU (last updated: 2025-06-27 18:08:15)
# All requested data for BIDU available in cache!
# Processing data request for AFRM from 2024-10-18 to 2025-06-24...
# Found cached data for AFRM (last updated: 2025-06-27 18:08:16)
# All requested data for AFRM available in cache!
# Processing data request for VZ from 2024-10-18 to 2025-06-24...
# Found cached data for VZ (last updated: 2025-06-27 18:08:16)
# All requested data for VZ available in cache!
# Processing data request for TTWO from 2024-10-18 to 2025-06-24...
# Found cached data for TTWO (last updated: 2025-06-27 18:08:16)
# All requested data for TTWO available in cache!
# Processing data request for CCL from 2024-10-18 to 2025-06-24...
# Found cached data for CCL (last updated: 2025-06-27 18:12:14)
# All requested data for CCL available in cache!
# Processing data request for NEM from 2024-10-18 to 2025-06-24...
# Found cached data for NEM (last updated: 2025-06-27 18:08:16)
# All requested data for NEM available in cache!
# Processing data request for BBAI from 2024-10-18 to 2025-06-24...
# Found cached data for BBAI (last updated: 2025-06-27 18:08:16)
# All requested data for BBAI available in cache!
# Processing data request for APLD from 2024-10-18 to 2025-06-24...
# Found cached data for APLD (last updated: 2025-06-27 18:08:17)
# All requested data for APLD available in cache!
# Processing data request for MDB from 2024-10-18 to 2025-06-24...
# Found cached data for MDB (last updated: 2025-06-27 18:08:17)
# All requested data for MDB available in cache!
# Processing data request for MCHP from 2024-10-18 to 2025-06-24...
# Found cached data for MCHP (last updated: 2025-06-27 18:08:17)
# All requested data for MCHP available in cache!
# Processing data request for T from 2024-10-18 to 2025-06-24...
# Found cached data for T (last updated: 2025-06-27 18:08:17)
# All requested data for T available in cache!
# Processing data request for TMUS from 2024-10-18 to 2025-06-24...
# Found cached data for TMUS (last updated: 2025-06-27 18:08:17)
# All requested data for TMUS available in cache!
# Processing data request for OXY from 2024-10-18 to 2025-06-24...
# Found cached data for OXY (last updated: 2025-06-27 18:12:11)
# All requested data for OXY available in cache!
# Processing data request for TEAM from 2024-10-18 to 2025-06-24...
# Found cached data for TEAM (last updated: 2025-06-27 18:08:18)
# All requested data for TEAM available in cache!
# Processing data request for MGM from 2024-10-18 to 2025-06-24...
# Found cached data for MGM (last updated: 2025-06-27 18:08:18)
# All requested data for MGM available in cache!
# Processing data request for NET from 2024-10-18 to 2025-06-24...
# Found cached data for NET (last updated: 2025-06-27 18:08:18)
# All requested data for NET available in cache!
# Processing data request for RIVN from 2024-10-18 to 2025-06-24...
# Found cached data for RIVN (last updated: 2025-06-27 18:08:18)
# All requested data for RIVN available in cache!
# Processing data request for PFE from 2024-10-18 to 2025-06-24...
# Found cached data for PFE (last updated: 2025-06-27 18:12:12)
# All requested data for PFE available in cache!
# Processing data request for CRS from 2024-10-18 to 2025-06-24...
# Found cached data for CRS (last updated: 2025-06-27 18:08:19)
# All requested data for CRS available in cache!
# Processing data request for CMCSA from 2024-10-18 to 2025-06-24...
# Found cached data for CMCSA (last updated: 2025-06-27 18:08:19)
# All requested data for CMCSA available in cache!
# Processing data request for ALB from 2024-10-18 to 2025-06-24...
# Found cached data for ALB (last updated: 2025-06-27 18:08:19)
# All requested data for ALB available in cache!
# Processing data request for DLR from 2024-10-18 to 2025-06-24...
# Found cached data for DLR (last updated: 2025-06-27 18:08:19)
# All requested data for DLR available in cache!
# Processing data request for KHC from 2024-10-18 to 2025-06-24...
# Found cached data for KHC (last updated: 2025-06-27 18:12:15)
# All requested data for KHC available in cache!
# Processing data request for PAYX from 2024-10-18 to 2025-06-24...
# Found cached data for PAYX (last updated: 2025-06-27 18:08:19)
# All requested data for PAYX available in cache!
# Processing data request for UAL from 2024-10-18 to 2025-06-24...
# Found cached data for UAL (last updated: 2025-06-27 18:08:20)
# All requested data for UAL available in cache!
# Processing data request for UPST from 2024-10-18 to 2025-06-24...
# Found cached data for UPST (last updated: 2025-06-27 18:08:20)
# All requested data for UPST available in cache!
# Processing data request for ILMN from 2024-10-18 to 2025-06-24...
# Found cached data for ILMN (last updated: 2025-06-27 18:08:20)
# All requested data for ILMN available in cache!
# Processing data request for STZ from 2024-10-18 to 2025-06-24...
# Found cached data for STZ (last updated: 2025-06-27 18:08:20)
# All requested data for STZ available in cache!
# Processing data request for LEU from 2024-10-18 to 2025-06-24...
# Found cached data for LEU (last updated: 2025-06-27 18:08:20)
# All requested data for LEU available in cache!
# Processing data request for CPNG from 2024-10-18 to 2025-06-24...
# Found cached data for CPNG (last updated: 2025-06-27 18:08:20)
# All requested data for CPNG available in cache!
# Processing data request for NEE from 2024-10-18 to 2025-06-24...
# Found cached data for NEE (last updated: 2025-06-27 18:12:12)
# All requested data for NEE available in cache!
# Processing data request for ACN from 2024-10-18 to 2025-06-24...
# Found cached data for ACN (last updated: 2025-06-27 18:08:20)
# All requested data for ACN available in cache!
# Processing data request for PENN from 2024-10-18 to 2025-06-24...
# Found cached data for PENN (last updated: 2025-06-27 18:08:21)
# All requested data for PENN available in cache!
# Processing data request for DD from 2024-10-18 to 2025-06-24...
# Found cached data for DD (last updated: 2025-06-27 18:08:25)
# All requested data for DD available in cache!
# Processing data request for TFC from 2024-10-18 to 2025-06-24...
# Found cached data for TFC (last updated: 2025-06-27 18:08:25)
# All requested data for TFC available in cache!
# Processing data request for SMR from 2024-10-18 to 2025-06-24...
# Found cached data for SMR (last updated: 2025-06-27 18:08:25)
# All requested data for SMR available in cache!
# Processing data request for MO from 2024-10-18 to 2025-06-24...
# Found cached data for MO (last updated: 2025-06-27 18:08:25)
# All requested data for MO available in cache!
# Processing data request for ABT from 2024-10-18 to 2025-06-24...
# Found cached data for ABT (last updated: 2025-06-27 18:08:26)
# All requested data for ABT available in cache!
# Processing data request for ET from 2024-10-18 to 2025-06-24...
# Found cached data for ET (last updated: 2025-06-27 18:08:26)
# All requested data for ET available in cache!
# Processing data request for TJX from 2024-10-18 to 2025-06-24...
# Found cached data for TJX (last updated: 2025-06-27 18:08:26)
# All requested data for TJX available in cache!
# Processing data request for RUN from 2024-10-18 to 2025-06-24...
# Found cached data for RUN (last updated: 2025-06-27 18:08:26)
# All requested data for RUN available in cache!
# Processing data request for DAL from 2024-10-18 to 2025-06-24...
# Found cached data for DAL (last updated: 2025-06-27 18:12:14)
# All requested data for DAL available in cache!
# Processing data request for COP from 2024-10-18 to 2025-06-24...
# Found cached data for COP (last updated: 2025-06-27 18:08:26)
# All requested data for COP available in cache!
# Processing data request for ACHR from 2024-10-18 to 2025-06-24...
# Found cached data for ACHR (last updated: 2025-06-27 18:08:26)
# All requested data for ACHR available in cache!
# Processing data request for FTAI from 2024-10-18 to 2025-06-24...
# Found cached data for FTAI (last updated: 2025-06-27 18:08:26)
# All requested data for FTAI available in cache!
# Processing data request for SHEL from 2024-10-18 to 2025-06-24...
# Found cached data for SHEL (last updated: 2025-06-27 18:08:27)
# All requested data for SHEL available in cache!
# Processing data request for STX from 2024-10-18 to 2025-06-24...
# Found cached data for STX (last updated: 2025-06-27 18:08:27)
# All requested data for STX available in cache!
# Processing data request for CLS from 2024-10-18 to 2025-06-24...
# Found cached data for CLS (last updated: 2025-06-27 18:08:27)
# All requested data for CLS available in cache!
# Processing data request for MP from 2024-10-18 to 2025-06-24...
# Found cached data for MP (last updated: 2025-06-27 18:08:27)
# All requested data for MP available in cache!
# Processing data request for EBAY from 2024-10-18 to 2025-06-24...
# Found cached data for EBAY (last updated: 2025-06-27 18:08:27)
# All requested data for EBAY available in cache!
# Processing data request for NUE from 2024-10-18 to 2025-06-24...
# Found cached data for NUE (last updated: 2025-06-27 18:08:27)
# All requested data for NUE available in cache!
# Processing data request for CHWY from 2024-10-18 to 2025-06-24...
# Found cached data for CHWY (last updated: 2025-06-27 18:08:27)
# All requested data for CHWY available in cache!
# Processing data request for QBTS from 2024-10-18 to 2025-06-24...
# Found cached data for QBTS (last updated: 2025-06-27 18:08:27)
# All requested data for QBTS available in cache!
# Processing data request for TIGR from 2024-10-18 to 2025-06-24...
# Found cached data for TIGR (last updated: 2025-06-27 18:08:28)
# All requested data for TIGR available in cache!
# Processing data request for CRDO from 2024-10-18 to 2025-06-24...
# Found cached data for CRDO (last updated: 2025-06-27 18:08:28)
# All requested data for CRDO available in cache!
# Processing data request for MMM from 2024-10-18 to 2025-06-24...
# Found cached data for MMM (last updated: 2025-06-27 18:08:28)
# All requested data for MMM available in cache!
# Processing data request for DKNG from 2024-10-18 to 2025-06-24...
# Found cached data for DKNG (last updated: 2025-06-27 18:08:28)
# All requested data for DKNG available in cache!
# Processing data request for RKT from 2024-10-18 to 2025-06-24...
# Found cached data for RKT (last updated: 2025-06-27 18:08:28)
# All requested data for RKT available in cache!
# Processing data request for COHR from 2024-10-18 to 2025-06-24...
# Found cached data for COHR (last updated: 2025-06-27 18:08:28)
# All requested data for COHR available in cache!
# Processing data request for RGTI from 2024-10-18 to 2025-06-24...
# Found cached data for RGTI (last updated: 2025-06-27 18:08:28)
# All requested data for RGTI available in cache!
# Processing data request for ELF from 2024-10-18 to 2025-06-24...
# Found cached data for ELF (last updated: 2025-06-27 18:08:28)
# All requested data for ELF available in cache!
# Processing data request for TPR from 2024-10-18 to 2025-06-24...
# Found cached data for TPR (last updated: 2025-06-27 18:08:29)
# All requested data for TPR available in cache!
# Processing data request for EQT from 2024-10-18 to 2025-06-24...
# Found cached data for EQT (last updated: 2025-06-27 18:08:31)
# All requested data for EQT available in cache!
# Processing data request for TOST from 2024-10-18 to 2025-06-24...
# Found cached data for TOST (last updated: 2025-06-27 18:08:31)
# All requested data for TOST available in cache!
# Processing data request for USB from 2024-10-18 to 2025-06-24...
# Found cached data for USB (last updated: 2025-06-27 18:08:31)
# All requested data for USB available in cache!
# Processing data request for KR from 2024-10-18 to 2025-06-24...
# Found cached data for KR (last updated: 2025-06-27 18:08:31)
# All requested data for KR available in cache!
# Processing data request for ZM from 2024-10-18 to 2025-06-24...
# Found cached data for ZM (last updated: 2025-06-27 18:08:31)
# All requested data for ZM available in cache!
# Processing data request for SHAK from 2024-10-18 to 2025-06-24...
# Found cached data for SHAK (last updated: 2025-06-27 18:08:32)
# All requested data for SHAK available in cache!
# Processing data request for JD from 2024-10-18 to 2025-06-24...
# Found cached data for JD (last updated: 2025-06-27 18:12:13)
# All requested data for JD available in cache!
# Processing data request for DOCU from 2024-10-18 to 2025-06-24...
# Found cached data for DOCU (last updated: 2025-06-27 18:08:32)
# All requested data for DOCU available in cache!
# Processing data request for SOUN from 2024-10-18 to 2025-06-24...
# Found cached data for SOUN (last updated: 2025-06-27 18:08:32)
# All requested data for SOUN available in cache!
# Processing data request for CLSK from 2024-10-18 to 2025-06-24...
# Found cached data for CLSK (last updated: 2025-06-27 18:08:32)
# All requested data for CLSK available in cache!
# Processing data request for BRBR from 2024-10-18 to 2025-06-24...
# Found cached data for BRBR (last updated: 2025-06-27 18:08:32)
# All requested data for BRBR available in cache!
# Processing data request for DECK from 2024-10-18 to 2025-06-24...
# Found cached data for DECK (last updated: 2025-06-27 18:08:32)
# All requested data for DECK available in cache!
# Processing data request for INSM from 2024-10-18 to 2025-06-24...
# Found cached data for INSM (last updated: 2025-06-27 18:08:33)
# All requested data for INSM available in cache!
# Processing data request for TWLO from 2024-10-18 to 2025-06-24...
# Found cached data for TWLO (last updated: 2025-06-27 18:08:33)
# All requested data for TWLO available in cache!
# Processing data request for SATS from 2024-10-18 to 2025-06-24...
# Found cached data for SATS (last updated: 2025-06-27 18:08:33)
# All requested data for SATS available in cache!
# Processing data request for VLO from 2024-10-18 to 2025-06-24...
# Found cached data for VLO (last updated: 2025-06-27 18:08:34)
# All requested data for VLO available in cache!
# Processing data request for BP from 2024-10-18 to 2025-06-24...
# Found cached data for BP (last updated: 2025-06-27 18:08:34)
# All requested data for BP available in cache!
# Processing data request for SCHW from 2024-10-18 to 2025-06-24...
# Found cached data for SCHW (last updated: 2025-06-27 18:08:34)
# All requested data for SCHW available in cache!
# Processing data request for LEVI from 2024-10-18 to 2025-06-24...
# Found cached data for LEVI (last updated: 2025-06-27 18:08:34)
# All requested data for LEVI available in cache!
# Processing data request for SE from 2024-10-18 to 2025-06-24...
# Found cached data for SE (last updated: 2025-06-27 18:08:35)
# All requested data for SE available in cache!
# Processing data request for BULL from 2024-10-18 to 2025-06-24...
# Found cached data for BULL (last updated: 2025-06-27 18:08:35)
# All requested data for BULL available in cache!
# Processing data request for MOS from 2024-10-18 to 2025-06-24...
# Found cached data for MOS (last updated: 2025-06-27 18:08:35)
# All requested data for MOS available in cache!
# Processing data request for DHR from 2024-10-18 to 2025-06-24...
# Found cached data for DHR (last updated: 2025-06-27 18:08:35)
# All requested data for DHR available in cache!
# Processing data request for DOW from 2024-10-18 to 2025-06-24...
# Found cached data for DOW (last updated: 2025-06-27 18:12:10)
# All requested data for DOW available in cache!
# Processing data request for AAL from 2024-10-18 to 2025-06-24...
# Found cached data for AAL (last updated: 2025-06-27 18:08:35)
# All requested data for AAL available in cache!
# Processing data request for VALE from 2024-10-18 to 2025-06-24...
# Found cached data for VALE (last updated: 2025-06-27 18:12:13)
# All requested data for VALE available in cache!
# Processing data request for AEM from 2024-10-18 to 2025-06-24...
# Found cached data for AEM (last updated: 2025-06-27 18:08:36)
# All requested data for AEM available in cache!
# Processing data request for ENVX from 2024-10-18 to 2025-06-24...
# Found cached data for ENVX (last updated: 2025-06-27 18:08:36)
# All requested data for ENVX available in cache!
# Processing data request for EL from 2024-10-18 to 2025-06-24...
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['PONY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2024-10-18 -> 2024-11-26) (Yahoo error = "Data doesn\'t exist for startDate = 1729224000, endDate = 1732597200")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CHYM']: YFPricesMissingError('possibly delisted; no price data found  (1d 2024-10-18 -> 2025-06-11) (Yahoo error = "Data doesn\'t exist for startDate = 1729224000, endDate = 1749614400")')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['GLXY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2024-10-18 -> 2025-05-15) (Yahoo error = "Data doesn\'t exist for startDate = 1729224000, endDate = 1747281600")')
# Found cached data for EL (last updated: 2025-06-27 18:08:36)
# All requested data for EL available in cache!
# Processing data request for KMB from 2024-10-18 to 2025-06-24...
# Found cached data for KMB (last updated: 2025-06-27 18:08:36)
# All requested data for KMB available in cache!
# Processing data request for THC from 2024-10-18 to 2025-06-24...
# Found cached data for THC (last updated: 2025-06-27 18:08:36)
# All requested data for THC available in cache!
# Processing data request for DG from 2024-10-18 to 2025-06-24...
# Found cached data for DG (last updated: 2025-06-27 18:08:36)
# All requested data for DG available in cache!
# Processing data request for VKTX from 2024-10-18 to 2025-06-24...
# Found cached data for VKTX (last updated: 2025-06-27 18:08:37)
# All requested data for VKTX available in cache!
# Processing data request for BROS from 2024-10-18 to 2025-06-24...
# Found cached data for BROS (last updated: 2025-06-27 18:08:37)
# All requested data for BROS available in cache!
# Processing data request for PONY from 2024-10-18 to 2025-06-24...
# Found cached data for PONY (last updated: 2025-06-27 18:14:08)
# Fetching missing data for PONY: 2024-10-18 to 2024-11-26
# Data download complete for PONY. Shape: (141, 5)
# Processing data request for NRG from 2024-10-18 to 2025-06-24...
# Found cached data for NRG (last updated: 2025-06-27 18:08:38)
# All requested data for NRG available in cache!
# Processing data request for XPEV from 2024-10-18 to 2025-06-24...
# Found cached data for XPEV (last updated: 2025-06-27 18:08:38)
# All requested data for XPEV available in cache!
# Processing data request for BMY from 2024-10-18 to 2025-06-24...
# Found cached data for BMY (last updated: 2025-06-27 18:12:12)
# All requested data for BMY available in cache!
# Processing data request for DLTR from 2024-10-18 to 2025-06-24...
# Found cached data for DLTR (last updated: 2025-06-27 18:08:38)
# All requested data for DLTR available in cache!
# Processing data request for ULS from 2024-10-18 to 2025-06-24...
# Found cached data for ULS (last updated: 2025-06-27 18:08:38)
# All requested data for ULS available in cache!
# Processing data request for FIS from 2024-10-18 to 2025-06-24...
# Found cached data for FIS (last updated: 2025-06-27 18:08:38)
# All requested data for FIS available in cache!
# Processing data request for BDX from 2024-10-18 to 2025-06-24...
# Found cached data for BDX (last updated: 2025-06-27 18:08:39)
# All requested data for BDX available in cache!
# Processing data request for GNRC from 2024-10-18 to 2025-06-24...
# Found cached data for GNRC (last updated: 2025-06-27 18:08:39)
# All requested data for GNRC available in cache!
# Processing data request for W from 2024-10-18 to 2025-06-24...
# Found cached data for W (last updated: 2025-06-27 18:08:39)
# All requested data for W available in cache!
# Processing data request for LUNR from 2024-10-18 to 2025-06-24...
# Found cached data for LUNR (last updated: 2025-06-27 18:08:39)
# All requested data for LUNR available in cache!
# Processing data request for AZN from 2024-10-18 to 2025-06-24...
# Found cached data for AZN (last updated: 2025-06-27 18:12:12)
# All requested data for AZN available in cache!
# Processing data request for WYNN from 2024-10-18 to 2025-06-24...
# Found cached data for WYNN (last updated: 2025-06-27 18:08:39)
# All requested data for WYNN available in cache!
# Processing data request for QUBT from 2024-10-18 to 2025-06-24...
# Found cached data for QUBT (last updated: 2025-06-27 18:08:39)
# All requested data for QUBT available in cache!
# Processing data request for GTLB from 2024-10-18 to 2025-06-24...
# Found cached data for GTLB (last updated: 2025-06-27 18:08:39)
# All requested data for GTLB available in cache!
# Processing data request for CHYM from 2024-10-18 to 2025-06-24...
# Found cached data for CHYM (last updated: 2025-06-27 18:14:08)
# Fetching missing data for CHYM: 2024-10-18 to 2025-06-11
# Data download complete for CHYM. Shape: (8, 5)
# Processing data request for LVS from 2024-10-18 to 2025-06-24...
# Found cached data for LVS (last updated: 2025-06-27 18:08:40)
# All requested data for LVS available in cache!
# Processing data request for AA from 2024-10-18 to 2025-06-24...
# Found cached data for AA (last updated: 2025-06-27 18:08:40)
# All requested data for AA available in cache!
# Processing data request for TSSI from 2024-10-18 to 2025-06-24...
# Found cached data for TSSI (last updated: 2025-06-27 18:08:40)
# All requested data for TSSI available in cache!
# Processing data request for WMB from 2024-10-18 to 2025-06-24...
# Found cached data for WMB (last updated: 2025-06-27 18:08:40)
# All requested data for WMB available in cache!
# Processing data request for IBKR from 2024-10-18 to 2025-06-24...
# Found cached data for IBKR (last updated: 2025-06-27 18:08:40)
# All requested data for IBKR available in cache!
# Processing data request for GBTC from 2024-10-18 to 2025-06-24...
# Found cached data for GBTC (last updated: 2025-06-27 18:08:40)
# ...
# Processing data request for ONDS from 2024-10-18 to 2025-06-24...
# Found cached data for ONDS (last updated: 2025-06-27 18:14:10)
# Fetching missing data for ONDS: 2025-06-24 to 2025-06-24
# Data download complete for ONDS. Shape: (168, 5)
# Processing data request for PAGS from 2024-10-18 to 2025-06-24...
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['PAGS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABR']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AEO']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MVST']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['COMP']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NEO']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DNN']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NOK']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['PSQH']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['RIG']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# Found cached data for PAGS (last updated: 2025-06-27 18:14:10)
# Fetching missing data for PAGS: 2025-06-24 to 2025-06-24
# Data download complete for PAGS. Shape: (168, 5)
# Processing data request for ABR from 2024-10-18 to 2025-06-24...
# Found cached data for ABR (last updated: 2025-06-27 18:14:11)
# Fetching missing data for ABR: 2025-06-24 to 2025-06-24
# Data download complete for ABR. Shape: (168, 5)
# Processing data request for AEO from 2024-10-18 to 2025-06-24...
# Found cached data for AEO (last updated: 2025-06-27 18:14:11)
# Fetching missing data for AEO: 2025-06-24 to 2025-06-24
# Data download complete for AEO. Shape: (168, 5)
# Processing data request for MVST from 2024-10-18 to 2025-06-24...
# Found cached data for MVST (last updated: 2025-06-27 18:14:11)
# Fetching missing data for MVST: 2025-06-24 to 2025-06-24
# Data download complete for MVST. Shape: (168, 5)
# Processing data request for COMP from 2024-10-18 to 2025-06-24...
# Found cached data for COMP (last updated: 2025-06-27 18:14:11)
# Fetching missing data for COMP: 2025-06-24 to 2025-06-24
# Data download complete for COMP. Shape: (168, 5)
# Processing data request for NEO from 2024-10-18 to 2025-06-24...
# Found cached data for NEO (last updated: 2025-06-27 18:14:11)
# Fetching missing data for NEO: 2025-06-24 to 2025-06-24
# Data download complete for NEO. Shape: (168, 5)
# Processing data request for DNN from 2024-10-18 to 2025-06-24...
# Found cached data for DNN (last updated: 2025-06-27 18:14:11)
# Fetching missing data for DNN: 2025-06-24 to 2025-06-24
# Data download complete for DNN. Shape: (168, 5)
# Processing data request for NOK from 2024-10-18 to 2025-06-24...
# Found cached data for NOK (last updated: 2025-06-27 18:14:12)
# Fetching missing data for NOK: 2025-06-24 to 2025-06-24
# Data download complete for NOK. Shape: (168, 5)
# Processing data request for PSQH from 2024-10-18 to 2025-06-24...
# Found cached data for PSQH (last updated: 2025-06-27 18:14:12)
# Fetching missing data for PSQH: 2025-06-24 to 2025-06-24
# Data download complete for PSQH. Shape: (168, 5)
# Processing data request for RIG from 2024-10-18 to 2025-06-24...
# Found cached data for RIG (last updated: 2025-06-27 18:14:12)
# Fetching missing data for RIG: 2025-06-24 to 2025-06-24
# Data download complete for RIG. Shape: (168, 5)
# Processing data request for SPCE from 2024-10-18 to 2025-06-24...
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPCE']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SLS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['INVZ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACB']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['EXK']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['RZLV']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['LAZR']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ASST']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# Found cached data for SPCE (last updated: 2025-06-27 18:14:12)
# Fetching missing data for SPCE: 2025-06-24 to 2025-06-24
# Data download complete for SPCE. Shape: (168, 5)
# Processing data request for SLS from 2024-10-18 to 2025-06-24...
# Found cached data for SLS (last updated: 2025-06-27 18:14:12)
# Fetching missing data for SLS: 2025-06-24 to 2025-06-24
# Data download complete for SLS. Shape: (168, 5)
# Processing data request for INVZ from 2024-10-18 to 2025-06-24...
# Found cached data for INVZ (last updated: 2025-06-27 18:14:12)
# Fetching missing data for INVZ: 2025-06-24 to 2025-06-24
# Data download complete for INVZ. Shape: (168, 5)
# Processing data request for ACB from 2024-10-18 to 2025-06-24...
# Found cached data for ACB (last updated: 2025-06-27 18:14:12)
# Fetching missing data for ACB: 2025-06-24 to 2025-06-24
# Data download complete for ACB. Shape: (168, 5)
# Processing data request for EXK from 2024-10-18 to 2025-06-24...
# Found cached data for EXK (last updated: 2025-06-27 18:14:12)
# Fetching missing data for EXK: 2025-06-24 to 2025-06-24
# Data download complete for EXK. Shape: (168, 5)
# Processing data request for RZLV from 2024-10-18 to 2025-06-24...
# Found cached data for RZLV (last updated: 2025-06-27 18:14:12)
# Fetching missing data for RZLV: 2025-06-24 to 2025-06-24
# Data download complete for RZLV. Shape: (168, 5)
# Processing data request for LAZR from 2024-10-18 to 2025-06-24...
# Found cached data for LAZR (last updated: 2025-06-27 18:14:12)
# Fetching missing data for LAZR: 2025-06-24 to 2025-06-24
# Data download complete for LAZR. Shape: (168, 5)
# Processing data request for ASST from 2024-10-18 to 2025-06-24...
# Found cached data for ASST (last updated: 2025-06-27 18:14:12)
# Fetching missing data for ASST: 2025-06-24 to 2025-06-24
# Data download complete for ASST. Shape: (168, 5)
# Processing data request for IQ from 2024-10-18 to 2025-06-24...
# Found cached data for IQ (last updated: 2025-06-27 18:14:13)
# Fetching missing data for IQ: 2025-06-24 to 2025-06-24
# Data download complete for IQ. Shape: (168, 5)
# Processing data request for AMPX from 2024-10-18 to 2025-06-24...
# Found cached data for AMPX (last updated: 2025-06-27 18:14:13)
# Fetching missing data for AMPX: 2025-06-24 to 2025-06-24
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMPX']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CLOV']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SLDP']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NAK']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['JMIA']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['RILY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['TLRY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IRBT']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['LPSN']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ARBE']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# Data download complete for AMPX. Shape: (168, 5)
# Processing data request for CLOV from 2024-10-18 to 2025-06-24...
# Found cached data for CLOV (last updated: 2025-06-27 18:14:13)
# Fetching missing data for CLOV: 2025-06-24 to 2025-06-24
# Data download complete for CLOV. Shape: (168, 5)
# Processing data request for SLDP from 2024-10-18 to 2025-06-24...
# Found cached data for SLDP (last updated: 2025-06-27 18:14:13)
# Fetching missing data for SLDP: 2025-06-24 to 2025-06-24
# Data download complete for SLDP. Shape: (168, 5)
# Processing data request for NAK from 2024-10-18 to 2025-06-24...
# Found cached data for NAK (last updated: 2025-06-27 18:14:13)
# Fetching missing data for NAK: 2025-06-24 to 2025-06-24
# Data download complete for NAK. Shape: (168, 5)
# Processing data request for JMIA from 2024-10-18 to 2025-06-24...
# Found cached data for JMIA (last updated: 2025-06-27 18:14:13)
# Fetching missing data for JMIA: 2025-06-24 to 2025-06-24
# Data download complete for JMIA. Shape: (168, 5)
# Processing data request for RILY from 2024-10-18 to 2025-06-24...
# Found cached data for RILY (last updated: 2025-06-27 18:14:13)
# Fetching missing data for RILY: 2025-06-24 to 2025-06-24
# Data download complete for RILY. Shape: (168, 5)
# Processing data request for TLRY from 2024-10-18 to 2025-06-24...
# Found cached data for TLRY (last updated: 2025-06-27 18:14:13)
# Fetching missing data for TLRY: 2025-06-24 to 2025-06-24
# Data download complete for TLRY. Shape: (168, 5)
# Processing data request for IRBT from 2024-10-18 to 2025-06-24...
# Found cached data for IRBT (last updated: 2025-06-27 18:14:14)
# Fetching missing data for IRBT: 2025-06-24 to 2025-06-24
# Data download complete for IRBT. Shape: (168, 5)
# Processing data request for LPSN from 2024-10-18 to 2025-06-24...
# Found cached data for LPSN (last updated: 2025-06-27 18:14:14)
# Fetching missing data for LPSN: 2025-06-24 to 2025-06-24
# Data download complete for LPSN. Shape: (168, 5)
# Processing data request for ARBE from 2024-10-18 to 2025-06-24...
# Found cached data for ARBE (last updated: 2025-06-27 18:14:14)
# Fetching missing data for ARBE: 2025-06-24 to 2025-06-24
# Data download complete for ARBE. Shape: (168, 5)
# Processing data request for QSI from 2024-10-18 to 2025-06-24...
# Found cached data for QSI (last updated: 2025-06-27 18:14:14)
# Fetching missing data for QSI: 2025-06-24 to 2025-06-24
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QSI']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HIVE']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IOVA']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CGC']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['OPEN']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CHPT']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BITF']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CAN']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-24 -> 2025-06-24)')
# Data download complete for QSI. Shape: (168, 5)
# Processing data request for HIVE from 2024-10-18 to 2025-06-24...
# Found cached data for HIVE (last updated: 2025-06-27 18:14:14)
# Fetching missing data for HIVE: 2025-06-24 to 2025-06-24
# Data download complete for HIVE. Shape: (168, 5)
# Processing data request for IOVA from 2024-10-18 to 2025-06-24...
# Found cached data for IOVA (last updated: 2025-06-27 18:14:14)
# Fetching missing data for IOVA: 2025-06-24 to 2025-06-24
# Data download complete for IOVA. Shape: (168, 5)
# Processing data request for CGC from 2024-10-18 to 2025-06-24...
# Found cached data for CGC (last updated: 2025-06-27 18:14:14)
# Fetching missing data for CGC: 2025-06-24 to 2025-06-24
# Data download complete for CGC. Shape: (168, 5)
# Processing data request for OPEN from 2024-10-18 to 2025-06-24...
# Found cached data for OPEN (last updated: 2025-06-27 18:14:14)
# Fetching missing data for OPEN: 2025-06-24 to 2025-06-24
# Data download complete for OPEN. Shape: (168, 5)
# Processing data request for CHPT from 2024-10-18 to 2025-06-24...
# Found cached data for CHPT (last updated: 2025-06-27 18:14:14)
# Fetching missing data for CHPT: 2025-06-24 to 2025-06-24
# Data download complete for CHPT. Shape: (168, 5)
# Processing data request for BITF from 2024-10-18 to 2025-06-24...
# Found cached data for BITF (last updated: 2025-06-27 18:14:14)
# Fetching missing data for BITF: 2025-06-24 to 2025-06-24
# Data download complete for BITF. Shape: (168, 5)
# Processing data request for CAN from 2024-10-18 to 2025-06-24...
# Found cached data for CAN (last updated: 2025-06-27 18:14:14)
# Fetching missing data for CAN: 2025-06-24 to 2025-06-24
# Data download complete for CAN. Shape: (168, 5)

# %%
plt.figure(figsize=(25, 6))
seri=pd.DataFrame(active_stocks_corr).median(axis=0)#.plot.bar()#['NVDA']
seri_sorted=seri.sort_values()
seri_sorted.head(100).plot.bar()
# Out:
# <Axes: >

# %%
seri_sorted
# Out:
# CRCL   -0.171371
# ETOR   -0.031329
# VOYG   -0.028936
# USAR   -0.005507
# UNH     0.014410
#           ...
# AAPL    0.424783
# DD      0.438224
# MCHP    0.442385
# QCOM    0.445171
# CAT     0.457787
# Length: 500, dtype: float64

# %%
active_options_stocks.loc[seri_sorted.index,].iloc[60:120]
# Out:
#        Price Change_Percent  Open_Volume  Put_Percent  Call_Percent PC_Ratio  \
# AMPX    4.23          -1.05         3536        10.41         89.59     0.12
# OPEN    0.58           8.64         7367        20.56         79.44     0.26
# SATS   28.40          11.55        24893        66.28         33.72     1.97
# TMUS  233.86           1.05         6048        50.10         49.90      1.0
# ZETA   15.51           1.11        27108        23.27         76.73      0.3
# NEM    56.74          -4.14        26496        23.59         76.41     0.31
# CRDO   93.85          -1.26         9113        22.48         77.52     0.29
# CF     90.57          -0.13         3303        62.03         37.97     1.63
# KC     12.36          -4.67         6075         0.46         99.54      0.0
# BTBT    2.10           5.28        50819         9.97         90.03     0.11
# K      79.04           0.28         4229        34.95         65.05     0.54
# SMLR   39.60           2.09         3708        22.63         77.37     0.29
# NVTS    6.67           0.91        41273        29.97         70.03     0.43
# EXK     4.80          -2.44         3950        10.38         89.62     0.12
# T      28.04           0.14        51022        53.81         46.19     1.17
# INVZ    1.47          -3.29        13304         7.01         92.99     0.08
# RILY    3.04           1.67         4050        20.25         79.75     0.25
# SERV   11.34           0.89        16046         8.91         91.09      0.1
# SRPT   17.32           0.52        18938        43.89         56.11     0.78
# APLD   10.56                      142094        12.87         87.13     0.15
# GEO    23.64           0.98         4976        50.40         49.60     1.02
# KTOS   46.01          11.31         9374        24.14         75.86     0.32
# ONDS    1.86           6.29        19548         5.96         94.04     0.06
# NN     15.10           0.13         8532         5.72         94.28     0.06
# NEO     7.29           1.75         3492         0.77         99.23      0.0
# EOSE    4.32          -4.85        31714        38.90         61.10     0.64
# IONQ   41.10          -0.05        72483        23.50         76.50     0.31
# AAOI   26.41           -4.9         9204        14.35         85.65     0.17
# PAAS   28.03          -3.78         6280        35.10         64.90     0.54
# ARRY    6.40          -1.62         8820        59.14         40.86     1.45
# SMR    38.80           1.46        27828        22.44         77.56     0.29
# NAK     1.52          -1.62         9376        14.05         85.95     0.16
# AMC     3.03           0.33        42934         9.33         90.67      0.1
# LI     27.30          -2.53         6245        72.54         27.46     2.64
# SMCI   48.56          -1.44       832316        17.71         82.29     0.22
# VST   196.51           3.21        22580        37.43         62.57      0.6
# RDDT  143.29          -0.46        49108        23.78         76.22     0.31
# RUM     9.24          -0.96        20979        23.35         76.65      0.3
# DNN     1.82          -1.36        13939         0.50         99.50     0.01
# DOCU   76.61            1.4         9865        11.81         88.19     0.13
# MP     32.79          -8.89        28502        49.61         50.39     0.98
# GBTC   84.44          -0.37         5759        19.27         80.73     0.24
# QXO    21.21          -2.35         5644        30.26         69.74     0.43
# HIMS   49.91           7.84       350956        44.59         55.41      0.8
# RKT    14.42          -0.48        57321        46.87         53.13     0.88
# HTZ     6.98          -7.67        26588        16.55         83.45      0.2
# PONY   14.00          -3.98        43232        17.31         82.69     0.21
# LUNR   11.28           -0.7        50540         8.99         91.01      0.1
# CGC     1.25           0.81         4456        20.60         79.40     0.26
# SLNO   84.34           0.38         3815        44.74         55.26     0.81
# TTWO  240.40           0.45         6514        45.58         54.42     0.84
# COMM    8.07          -1.47        23185        26.18         73.82     0.35
# LPSN    0.94          -3.12        10647         9.02         90.98      0.1
# ACB     4.23          -0.82         4621        47.07         52.93     0.89
# EQT    58.04          -0.19        13536        34.59         65.41     0.53
# IRBT    3.45           4.23         3241        33.79         66.21     0.51
# NXT    58.54          -0.07         3763        75.07         24.93     3.01
# SRAD   27.52            1.4         4180         3.16         96.84     0.03
# AVAV  275.88           1.29        13494        37.96         62.04     0.61
# CIFR    4.30           2.63        39741        26.07         73.93     0.35
#
#      Next_Earning  Open_Volume_Priced  Open_Volume_Priced_ranked
# AMPX   2025-08-07            14957.28                      0.036
# OPEN   2025-07-31             4272.86                      0.008
# SATS   2025-07-30           706961.20                      0.554
# TMUS   2025-07-23          1414385.28                      0.684
# ZETA   2025-07-30           420445.08                      0.446
# NEM    2025-07-17          1503383.04                      0.696
# CRDO   2025-08-27           855255.05                      0.598
# CF     2025-08-06           299152.71                      0.356
# KC     2025-08-26            75087.00                      0.146
# BTBT   2025-08-14           106719.90                      0.184
# K      2025-07-31           334260.16                      0.390
# SMLR   2025-08-11           146836.80                      0.238
# NVTS   2025-08-18           275290.91                      0.340
# EXK    2025-08-12            18960.00                      0.046
# T      2025-07-23          1430656.88                      0.686
# INVZ   2025-08-06            19556.88                      0.050
# RILY   2025-07-24            12312.00                      0.026
# SERV   2025-08-19           181961.64                      0.276
# SRPT   2025-07-30           328006.16                      0.376
# APLD   2025-08-21          1500512.64                      0.692
# GEO    2025-08-06           117632.64                      0.200
# KTOS   2025-07-31           431297.74                      0.450
# ONDS   2025-08-18            36359.28                      0.076
# NN     2025-08-06           128833.20                      0.212
# NEO    2025-07-30            25456.68                      0.064
# EOSE   2025-08-06           137004.48                      0.224
# IONQ   2025-08-07          2979051.30                      0.790
# AAOI   2025-07-31           243077.64                      0.322
# PAAS   2025-08-06           176028.40                      0.262
# ARRY   2025-08-12            56448.00                      0.110
# SMR    2025-08-06          1079726.40                      0.636
# NAK    2025-08-19            14251.52                      0.030
# AMC    2025-08-06           130090.02                      0.218
# LI     2025-09-02           170488.50                      0.254
# SMCI   2025-08-12         40417264.96                      0.964
# VST    2025-08-06          4437195.80                      0.836
# RDDT   2025-08-12          7036685.32                      0.876
# RUM    2025-08-18           193845.96                      0.300
# DNN    2025-08-07            25368.98                      0.062
# DOCU   2025-09-04           755757.65                      0.568
# MP     2025-07-31           934580.58                      0.610
# GBTC                        486289.96                      0.472
# QXO    2025-08-12           119709.24                      0.204
# HIMS   2025-08-11         17516213.96                      0.936
# RKT    2025-07-31           826568.82                      0.592
# HTZ    2025-08-07           185584.24                      0.282
# PONY   2026-03-31           605248.00                      0.514
# LUNR   2025-08-19           570091.20                      0.494
# CGC    2025-08-08             5570.00                      0.010
# SLNO   2025-08-06           321757.10                      0.370
# TTWO   2025-08-11          1565965.60                      0.700
# COMM   2025-07-31           187102.95                      0.284
# LPSN   2025-08-12            10008.18                      0.020
# ACB    2025-08-07            19546.83                      0.048
# EQT    2025-07-23           785629.44                      0.582
# IRBT   2025-07-23            11181.45                      0.022
# NXT    2025-07-23           220286.02                      0.314
# SRAD   2025-08-13           115033.60                      0.196
# AVAV   2025-09-03          3722724.72                      0.818
# CIFR   2025-08-12           170886.30                      0.256

# %%
seri.loc['TSLA']
# Out:
# np.float64(0.25415761651064706)

# %%
seri.sort_values()
# Out:
# CRCL   -0.146264
# HNGE   -0.098829
# KR     -0.012946
# USAR   -0.007481
# BULL    0.041386
#           ...
# NTRS    0.407891
# QCOM    0.414986
# AAPL    0.416698
# SLB     0.421534
# DOW     0.454954
# Length: 300, dtype: float64

# %%
del all_price['TLT']
del all_price['IEF']

# %%
res_df=create_stock_correlation_network(all_price,252*10,output='df',transformation='log')
clustered_heatmap(res_df,cmap='coolwarm')
# Out:
# (<seaborn.matrix.ClusterGrid at 0x2bd3d8610>,
#              DOW       XOM       CVX       OXY       SLB        SU      VALE  \
#  DOW    1.000000  0.613141  0.580128  0.572780  0.620098  0.569110  0.521487
#  XOM    0.613141  1.000000  0.835311  0.719212  0.765391  0.741954  0.430675
#  CVX    0.580128  0.835311  1.000000  0.689160  0.756170  0.737990  0.455049
#  OXY    0.572780  0.719212  0.689160  1.000000  0.715099  0.671287  0.384420
#  SLB    0.620098  0.765391  0.756170  0.715099  1.000000  0.719488  0.429668
#  SU     0.569110  0.741954  0.737990  0.671287  0.719488  1.000000  0.443781
#  VALE   0.521487  0.430675  0.455049  0.384420  0.429668  0.443781  1.000000
#  RIO    0.563878  0.483637  0.513512  0.400693  0.480472  0.487877  0.766787
#  DAL    0.504026  0.386186  0.431646  0.357897  0.420271  0.407490  0.314574
#  CCL    0.481416  0.384646  0.426331  0.402545  0.453456  0.409818  0.278048
#  MTCH   0.272435  0.175526  0.200408  0.149362  0.176632  0.194859  0.199864
#  JD     0.274717  0.176852  0.191022  0.158153  0.181484  0.186902  0.313592
#  TSLA   0.264148  0.176464  0.226694  0.203842  0.209860  0.218799  0.221340
#  QCOM   0.422859  0.305346  0.339942  0.264605  0.319604  0.312396  0.320711
#  AVGO   0.409887  0.292238  0.359785  0.275494  0.322963  0.300103  0.307684
#  PYPL   0.337382  0.238773  0.290775  0.222594  0.234038  0.241662  0.286837
#  AAPL   0.434095  0.322878  0.352646  0.282345  0.300255  0.291930  0.319321
#  GOOGL  0.378476  0.287253  0.326237  0.263342  0.284379  0.285565  0.289618
#  TGT    0.338647  0.237185  0.261975  0.183208  0.219376  0.186425  0.191411
#  TMO    0.319915  0.232908  0.290102  0.200527  0.201110  0.187750  0.308081
#  UPS    0.484044  0.345357  0.346607  0.292637  0.305996  0.247592  0.287179
#  NKE    0.447840  0.321253  0.338736  0.253483  0.293476  0.277745  0.273824
#  PEP    0.367002  0.323710  0.331798  0.202606  0.223099  0.221232  0.239409
#  MDLZ   0.365276  0.319104  0.352091  0.202979  0.239244  0.257158  0.255019
#  DEO    0.387608  0.326476  0.402356  0.281079  0.315202  0.333740  0.291387
#  BF-B   0.422404  0.311569  0.309502  0.208136  0.263772  0.246397  0.263400
#  KHC    0.375593  0.299750  0.315594  0.240994  0.279093  0.235443  0.219947
#  GIS    0.165945  0.157828  0.174728  0.072419  0.092165  0.092617  0.136642
#  NEE    0.304554  0.257470  0.281366  0.147608  0.165573  0.189463  0.191250
#  VZ     0.334071  0.306007  0.306267  0.186391  0.212128  0.204642  0.202648
#  UNH    0.268176  0.296531  0.358069  0.217434  0.259346  0.248278  0.215311
#  HUM    0.248134  0.239955  0.287918  0.192447  0.220520  0.209186  0.174413
#  PFE    0.331656  0.284555  0.297523  0.214148  0.219327  0.227378  0.238979
#  MRK    0.281048  0.292950  0.329331  0.200253  0.234238  0.230275  0.210685
#  JNJ    0.313996  0.316649  0.344749  0.208676  0.229505  0.215003  0.220858
#  AZN    0.259966  0.205055  0.250399  0.155116  0.172293  0.205531  0.217948
#  BMY    0.288932  0.258450  0.297050  0.181856  0.213857  0.211218  0.198622
#
#              RIO       DAL       CCL  ...       GIS       NEE        VZ  \
#  DOW    0.563878  0.504026  0.481416  ...  0.165945  0.304554  0.334071
#  XOM    0.483637  0.386186  0.384646  ...  0.157828  0.257470  0.306007
#  CVX    0.513512  0.431646  0.426331  ...  0.174728  0.281366  0.306267
#  OXY    0.400693  0.357897  0.402545  ...  0.072419  0.147608  0.186391
#  SLB    0.480472  0.420271  0.453456  ...  0.092165  0.165573  0.212128
#  SU     0.487877  0.407490  0.409818  ...  0.092617  0.189463  0.204642
#  VALE   0.766787  0.314574  0.278048  ...  0.136642  0.191250  0.202648
#  RIO    1.000000  0.367129  0.313070  ...  0.141508  0.222536  0.222683
#  DAL    0.367129  1.000000  0.702097  ...  0.060726  0.203312  0.194465
#  CCL    0.313070  0.702097  1.000000  ... -0.003536  0.182630  0.158166
#  MTCH   0.239463  0.284363  0.286840  ...  0.063112  0.226708  0.120705
#  JD     0.361979  0.231073  0.237448  ...  0.065856  0.154132  0.101067
#  TSLA   0.250057  0.302135  0.318428  ...  0.040919  0.177601  0.058227
#  QCOM   0.362450  0.375522  0.352466  ...  0.086319  0.230055  0.169757
#  AVGO   0.359184  0.383385  0.385983  ...  0.071744  0.230581  0.133141
#  PYPL   0.320842  0.332742  0.339549  ...  0.106053  0.295827  0.164996
#  AAPL   0.362749  0.368337  0.360501  ...  0.202223  0.317790  0.229458
#  GOOGL  0.318632  0.358158  0.378846  ...  0.111063  0.270183  0.200139
#  TGT    0.234709  0.262709  0.242473  ...  0.226416  0.242809  0.238492
#  TMO    0.340400  0.270338  0.223092  ...  0.266510  0.353357  0.276134
#  UPS    0.330810  0.332825  0.296430  ...  0.239354  0.299240  0.288911
#  NKE    0.325734  0.413255  0.401878  ...  0.193607  0.319356  0.234188
#  PEP    0.265198  0.236951  0.189432  ...  0.556941  0.531019  0.453247
#  MDLZ   0.280206  0.281271  0.232491  ...  0.593970  0.473364  0.420626
#  DEO    0.377917  0.373766  0.368011  ...  0.281647  0.396231  0.292818
#  BF-B   0.290960  0.265421  0.228797  ...  0.373470  0.407156  0.335345
#  KHC    0.241657  0.218827  0.203135  ...  0.528304  0.341572  0.358458
#  GIS    0.141508  0.060726 -0.003536  ...  1.000000  0.342996  0.368973
#  NEE    0.222536  0.203312  0.182630  ...  0.342996  1.000000  0.407537
#  VZ     0.222683  0.194465  0.158166  ...  0.368973  0.407537  1.000000
#  UNH    0.245133  0.259497  0.229948  ...  0.246453  0.272341  0.277435
#  HUM    0.203315  0.216574  0.217224  ...  0.181866  0.226199  0.214996
#  PFE    0.262583  0.237423  0.197821  ...  0.268919  0.295008  0.344742
#  MRK    0.228918  0.207096  0.163870  ...  0.349334  0.294651  0.353925
#  JNJ    0.270890  0.198217  0.146542  ...  0.408963  0.388599  0.417782
#  AZN    0.282895  0.204430  0.159303  ...  0.236334  0.295475  0.236576
#  BMY    0.222663  0.214817  0.182414  ...  0.255753  0.240953  0.261582
#
#              UNH       HUM       PFE       MRK       JNJ       AZN       BMY
#  DOW    0.268176  0.248134  0.331656  0.281048  0.313996  0.259966  0.288932
#  XOM    0.296531  0.239955  0.284555  0.292950  0.316649  0.205055  0.258450
#  CVX    0.358069  0.287918  0.297523  0.329331  0.344749  0.250399  0.297050
#  OXY    0.217434  0.192447  0.214148  0.200253  0.208676  0.155116  0.181856
#  SLB    0.259346  0.220520  0.219327  0.234238  0.229505  0.172293  0.213857
#  SU     0.248278  0.209186  0.227378  0.230275  0.215003  0.205531  0.211218
#  VALE   0.215311  0.174413  0.238979  0.210685  0.220858  0.217948  0.198622
#  RIO    0.245133  0.203315  0.262583  0.228918  0.270890  0.282895  0.222663
#  DAL    0.259497  0.216574  0.237423  0.207096  0.198217  0.204430  0.214817
#  CCL    0.229948  0.217224  0.197821  0.163870  0.146542  0.159303  0.182414
#  MTCH   0.202482  0.162241  0.170908  0.143977  0.149775  0.166888  0.151852
#  JD     0.162464  0.101048  0.167225  0.131503  0.147189  0.203990  0.158777
#  TSLA   0.172867  0.161537  0.122071  0.122598  0.093642  0.173348  0.113782
#  QCOM   0.256739  0.188490  0.234271  0.207880  0.219959  0.239072  0.193712
#  AVGO   0.262706  0.203032  0.212350  0.210631  0.172527  0.233530  0.172979
#  PYPL   0.251888  0.201058  0.232549  0.225049  0.227547  0.254749  0.215077
#  AAPL   0.335581  0.281687  0.305953  0.295709  0.324164  0.312320  0.270525
#  GOOGL  0.322028  0.249809  0.274631  0.252630  0.277279  0.277797  0.226062
#  TGT    0.195971  0.165621  0.244540  0.221607  0.243146  0.187270  0.215048
#  TMO    0.376796  0.315526  0.440893  0.447420  0.434145  0.375226  0.377375
#  UPS    0.278248  0.228416  0.317903  0.261375  0.339572  0.248492  0.259155
#  NKE    0.248285  0.221235  0.267637  0.275378  0.282315  0.255226  0.245005
#  PEP    0.387999  0.295516  0.402936  0.425864  0.551901  0.350218  0.345517
#  MDLZ   0.361441  0.274744  0.366458  0.429000  0.491025  0.367993  0.310945
#  DEO    0.315800  0.267382  0.313938  0.357818  0.366075  0.395233  0.272369
#  BF-B   0.284154  0.241509  0.318946  0.294104  0.380431  0.257896  0.268698
#  KHC    0.278338  0.221282  0.293891  0.321669  0.372584  0.243534  0.242167
#  GIS    0.246453  0.181866  0.268919  0.349334  0.408963  0.236334  0.255753
#  NEE    0.272341  0.226199  0.295008  0.294651  0.388599  0.295475  0.240953
#  VZ     0.277435  0.214996  0.344742  0.353925  0.417782  0.236576  0.261582
#  UNH    1.000000  0.679774  0.347396  0.350869  0.400194  0.281027  0.324669
#  HUM    0.679774  1.000000  0.305106  0.297786  0.321340  0.229164  0.258836
#  PFE    0.347396  0.305106  1.000000  0.480356  0.525104  0.386533  0.446883
#  MRK    0.350869  0.297786  0.480356  1.000000  0.517664  0.404475  0.395138
#  JNJ    0.400194  0.321340  0.525104  0.517664  1.000000  0.389077  0.446593
#  AZN    0.281027  0.229164  0.386533  0.404475  0.389077  1.000000  0.354968
#  BMY    0.324669  0.258836  0.446883  0.395138  0.446593  0.354968  1.000000
#
#  [37 rows x 37 columns])

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, FFMpegWriter

# Generate sample data
x = np.linspace(0, 4*np.pi, 100)
y = np.sin(x)

# Setup figure and axis
fig, ax = plt.subplots(figsize=(8,4))
line, = ax.plot([], [], lw=2)
ax.set_xlim(0, 4*np.pi)
ax.set_ylim(-1.1, 1.1)

# Animation functions
def init():
    line.set_data([], [])
    return line,

def update(frame):
    line.set_data(x[:frame], y[:frame])
    return line,

# Create animation
ani = FuncAnimation(fig, update, frames=len(x)+1,
                    init_func=init, blit=True,
                    interval=50)

# Save as MP4 video
writer = FFMpegWriter(fps=15, bitrate=1800)
ani.save("animation.mp4", writer=writer)
plt.close()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, FFMpegWriter

# Generate static x-values (0 to 4π with 500 points)
x = np.linspace(0, 4*np.pi, 500)
t_values = np.linspace(0.1, 2, 200)  # Time parameter evolution

# Configure plot
fig, ax = plt.subplots(figsize=(10, 4))
line, = ax.plot([], [], lw=2, color='crimson')
ax.set_xlim(0, 4*np.pi)
ax.set_ylim(-1.1, 1.1)
ax.grid(alpha=0.4)

# Animation functions
def init():
    line.set_data([], [])
    return line,

def update(t):
    y = np.sin(x * t)  # Core equation y = sin(xt)
    line.set_data(x, y)
    ax.set_title(f'y = sin(xt) | t = {t:.2f}', fontsize=12)
    return line,

# Create animation
ani = FuncAnimation(fig, update, frames=t_values,
                    init_func=init, blit=True, interval=50)

# Save as video (requires FFmpeg)
writer = FFMpegWriter(fps=20, bitrate=2000)
ani.save("sine_evolution.mp4", writer=writer)
plt.close()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 all_price=dict()
#       2 for stock in symbols:
# ----> 3     data =  downloader(stock, start_date,end_date)
#       4     all_price[stock]=data
#
# NameError: name 'downloader' is not defined

# %%
plot_network_and_heatmap(all_price,200)
# Out:
# Error: create_stock_correlation_network function not available
# (None, None)

# %%
analyze_correlation_network(res,top_n=10)
# Out:
# {'num_nodes': 29,
#  'num_edges': 406,
#  'avg_correlation': np.float64(0.31968025438490366),
#  'max_correlation': np.float64(0.9412442671096187),
#  'min_correlation': np.float64(-0.8017368691514044),
#  'top_correlations': [{'stocks': ('DOW', 'MRK'),
#    'correlation': np.float64(0.9412442671096187)},
#   {'stocks': ('DOW', 'TGT'), 'correlation': np.float64(0.9331598847811812)},
#   {'stocks': ('DOW', 'PEP'), 'correlation': np.float64(0.9285619873561776)},
#   {'stocks': ('PEP', 'MRK'), 'correlation': np.float64(0.9165853969994254)},
#   {'stocks': ('DOW', 'PFE'), 'correlation': np.float64(0.8986140756135339)},
#   {'stocks': ('DOW', 'NKE'), 'correlation': np.float64(0.8969778554075569)},
#   {'stocks': ('PFE', 'MRK'), 'correlation': np.float64(0.888137615669571)},
#   {'stocks': ('TGT', 'UPS'), 'correlation': np.float64(0.8880850861893352)},
#   {'stocks': ('DOW', 'OXY'), 'correlation': np.float64(0.883548736338841)},
#   {'stocks': ('OXY', 'SLB'), 'correlation': np.float64(0.8832685392449435)}]}

# %%
# def download_and_calculate_volatility(symbol, start_date, end_date, window=20):
#     """
#     Enhanced function to calculate both volatility measures
#     """
#     print(f"Downloading data for {symbol}...")
#     data = yf.download(symbol, start=start_date, end=end_date)
    
#     # Calculate both volatility measures
#     data['GK_Volatility'] = garman_klass_volatility(data, window)
#     data['YZ_Volatility'] = yang_zhang_volatility(data, window)
    
    # return data
def plot_volatility_comparison(data, symbol):
    """
    Enhanced visualization with both volatility measures and current values
    """
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10))
    
    # Price plot
    ax1.plot(data.index, data['Close'], label='Closing Price')
    ax1.set_title(f'{symbol} - Price and Volatility Comparison')
    ax1.set_ylabel('Price ($)')
    ax1.grid(True)
    
    # Get the latest volatility values
    latest_gk = data['GK_Volatility'].iloc[-1]
    latest_yz = data['YZ_Volatility'].iloc[-1]
    
    # Volatility comparison plot
    ax2.plot(data.index, data['GK_Volatility'], 
             label=f'Garman-Klass (Current: {latest_gk:.2%})', color='blue',alpha=0.5)
    ax2.plot(data.index, data['YZ_Volatility'], 
             label=f'Yang-Zhang (Current: {latest_yz:.2%})', color='red',alpha=0.3)
    ax2.axhline(y=latest_gk, color='blue', linestyle='--', alpha=1)
    ax2.axhline(y=latest_yz, color='red', linestyle='--', alpha=1)
    # Add text annotation with current values
    # ax2.text(0.02, 0.98, f'Latest Volatility:\nGK: {latest_gk:.2%}\nYZ: {latest_yz:.2%}', 
    #          transform=ax2.transAxes, verticalalignment='top',
    #          bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))
    
    ax2.set_title('Volatility Comparison')
    ax2.set_ylabel('Annualized Volatility')
    ax2.legend()
    ax2.grid(True)
    
    plt.tight_layout()
    plt.show()

# # Example usage
# if __name__ == "__main__":
#     # Parameters
#     symbol = 'AAPL'
#     start_date = '2019-01-01'
#     end_date = '2025-05-22' 
#     window = 20
    
#     # Download data and calculate volatility
#     stock_data = download_and_calculate_gk_volatility(symbol, start_date, end_date, window)
    
#     # Display results
#     print(f"\nGarman-Klass Volatility for {symbol}:")
#     print("=" * 50)
#     print(stock_data[['Close', 'GK_Volatility']].tail(10))
    
#     # Calculate summary statistics
#     avg_volatility = stock_data['GK_Volatility'].mean()
#     min_volatility = stock_data['GK_Volatility'].min()
#     max_volatility = stock_data['GK_Volatility'].max()
    
#     print(f"\nSummary Statistics:")
#     print(f"Average Volatility: {avg_volatility:.4f}")
#     print(f"Minimum Volatility: {min_volatility:.4f}")
#     print(f"Maximum Volatility: {max_volatility:.4f}")
    
#     # Plot the results
#     plot_volatility(stock_data, symbol)
    
#     # Compare multiple stocks
#     symbols = ['AAPL', 'GOOGL', 'MSFT', 'TSLA']
#     comparison_data = {}
    
#     print(f"\nComparing Garman-Klass Volatility across stocks:")
#     print("=" * 60)
    
#     for stock in symbols:
#         try:
#             data = download_and_calculate_gk_volatility(stock, start_date, end_date, window)
#             latest_vol = data['GK_Volatility'].iloc[-1]
#             avg_vol = data['GK_Volatility'].mean()
#             comparison_data[stock] = {'Latest': latest_vol, 'Average': avg_vol}
#             print(f"{stock}: Latest = {latest_vol:.4f}, Average = {avg_vol:.4f}")
#         except Exception as e:
#             print(f"Error processing {stock}: {e}")
    
#     # Create comparison DataFrame
#     comparison_df = pd.DataFrame(comparison_data).T
#     print(f"\nVolatility Comparison:")
#     print(comparison_df.round(4))

# %%
ref_FOC = FOC()

# %%
def example_result_callback(result):
    print("Result from target function:", result)

# %%
def example_result_callback(result,ls):
    ls.append(result)
    raise Exception('stop')

# %%
ls=[]
ref_FOC.create_quote_stream_options_price_data(20,'AMC---250530C00003000',result_callback=lambda x:example_result_callback(x,ls))
# Out:
# Exception in thread Thread-54 (_run):
# Traceback (most recent call last):
#   File "/Users/williamxu/anaconda3/lib/python3.11/site-packages/FOC/main.py", line 116, in json_extract_node
#     json_data = json_data[key]
#                 ~~~~~~~~~^^^^^
# TypeError: 'NoneType' object is not subscriptable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/williamxu/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/Users/williamxu/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/Users/williamxu/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/williamxu/anaconda3/lib/python3.11/site-packages/FOC/intervalrunner.py", line 23, in _run
#     result = self.target_func(*self.func_args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/williamxu/anaconda3/lib/python3.11/site-packages/FOC/main.py", line 282, in get_options_price_data
#     list_values.append(self.json_extract_node(options_data,['data',options_data_fieldtype,'optionChainListData']).values())
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/williamxu/anaconda3/lib/python3.11/site-packages/FOC/main.py", line 119, in json_extract_node
#     raise ValueError("Invalid json keys.")
# ValueError: Invalid json keys.

# %%
ls=[]
ref_FOC.create_quote_stream_options_price_data(20,'AAPL--250530C00200000',result_callback=lambda x:example_result_callback(x,ls))
# Out:
# Exception in thread Thread-55 (_run):
# Traceback (most recent call last):
#   File "/Users/williamxu/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/Users/williamxu/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/Users/williamxu/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/williamxu/anaconda3/lib/python3.11/site-packages/FOC/intervalrunner.py", line 25, in _run
#     self.result_callback(result)
#   File "/var/folders/_q/zvg1j91x7sx_8_rt3f62v0ph0000gn/T/ipykernel_81809/2323725644.py", line 2, in <lambda>
#   File "/var/folders/_q/zvg1j91x7sx_8_rt3f62v0ph0000gn/T/ipykernel_81809/3823222416.py", line 3, in example_result_callback
# Exception: stop

# %%
ls[0]
# Out:
# label                 Last Sale    Net Day High Day Low Volume Prev Close  \
# AAPL--250530C00200000
# value                      1.62  -2.68     2.64    1.41  25575        4.3
#
# label                  Open Open Interest Tick  Bid  ... Contract Low Market  \
# AAPL--250530C00200000                                ...
# value                  1.53          3540       1.6  ...         1.41  OPRAC
#
# label                    Delta    Gamma      Rho     Theta     Vega   Impvol  \
# AAPL--250530C00200000
# value                  0.30546  0.04101  0.01112  -0.21995  0.09476  0.31613
#
# label                            timestamp        contract_symbol
# AAPL--250530C00200000
# value                  2025-05-25 15:42:00  AAPL--250530C00200000
#
# [1 rows x 24 columns]

# %%
ls=[]
ref_FOC.create_quote_stream_options_price_data(20,'TSLA--250530C00440000',result_callback=lambda x:example_result_callback(x,ls))
# Out:
# Exception in thread Thread-57 (_run):
# Traceback (most recent call last):
#   File "/Users/williamxu/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/Users/williamxu/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/Users/williamxu/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/williamxu/anaconda3/lib/python3.11/site-packages/FOC/intervalrunner.py", line 25, in _run
#     self.result_callback(result)
#   File "/var/folders/_q/zvg1j91x7sx_8_rt3f62v0ph0000gn/T/ipykernel_81809/1577127683.py", line 2, in <lambda>
#   File "/var/folders/_q/zvg1j91x7sx_8_rt3f62v0ph0000gn/T/ipykernel_81809/3823222416.py", line 3, in example_result_callback
# Exception: stop

# %%
ls[0]
# Out:
#     price  nlsShareVolume   nlsTime   nlsVolume previousClose todayHighLow  \
# 0  195.27           850.0  16:00:00  78,432,918       $201.36            /
#
#   fiftyTwoWeekHighLow
# 0    $260.1/$169.2101

# %%
ls=[]
ref_FOC.create_quote_stream_stock_price(20,'AAPL',last_n_price = 50,result_callback=lambda x:example_result_callback(x,ls))
# Out:
# Exception in thread Thread-74 (_run):
# Traceback (most recent call last):
#   File "/Users/williamxu/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/Users/williamxu/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/Users/williamxu/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/williamxu/anaconda3/lib/python3.11/site-packages/FOC/intervalrunner.py", line 25, in _run
#     self.result_callback(result)
#   File "/var/folders/_q/zvg1j91x7sx_8_rt3f62v0ph0000gn/T/ipykernel_81809/625373052.py", line 2, in <lambda>
#   File "/var/folders/_q/zvg1j91x7sx_8_rt3f62v0ph0000gn/T/ipykernel_81809/3823222416.py", line 3, in example_result_callback
# Exception: stop

# %%
ref_FOC = FOC()

# Options Chain of AAPL CALL options for 6 October 2023
options_chain = ref_FOC.get_options_chain("AAPL","2023-10-06",OptionType.CALL)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       1 ref_FOC = FOC()
#       3 # Options Chain of AAPL CALL options for 6 October 2023
# ----> 4 options_chain = ref_FOC.get_options_chain('TSLA--250530C00440000')
#
# TypeError: FOC.get_options_chain() missing 2 required positional arguments: 'expiration_date' and 'option_type'

# %%
stock='TGT'
res_dict=dict()
window=20
p_val=dict()
try:
    data =  downloader(stock, start_date,end_date)
    data['GK_Volatility'] = garman_klass_volatility(data, window)
    data['YZ_Volatility'] = yang_zhang_volatility(data, window)
    plot_volatility_comparison(data, stock)
    #larger_proportion(res_dict[stock]['YZ_Volatility'].dropna(),0.5)
    # comparison_data[stock] = {
    #     'GK_Mean': data['GK_Volatility'].mean(),
    #     'YZ_Mean': data['YZ_Volatility'].mean(),
    #     'Volatility_Ratio': data['YZ_Volatility'].mean() / data['GK_Volatility'].mean()
    # }
    res_dict[stock]=data
except Exception as e:
    print(f"Error processing {stock}: {e}")

for stock,data in res_dict.items():
    p_val[stock]={"YZ-pval":latest_pval(data['YZ_Volatility']),"GK-pval":latest_pval(data['GK_Volatility'])}
    print('{}: YZ-pval: {:.3f},  GK-pval: {:.3f}'.format(stock,p_val[stock]["YZ-pval"], p_val[stock]["GK-pval"]))
# Out:
# Processing data request for TGT from 2007-01-03 to 2025-06-18...
# Found cached data for TGT (last updated: 2025-06-20 16:00:07)
# All requested data for TGT available in cache!
# TGT: YZ-pval: 0.149,  GK-pval: 0.206
# /var/folders/_q/zvg1j91x7sx_8_rt3f62v0ph0000gn/T/ipykernel_16333/2872722370.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   latest_pval=lambda s: larger_proportion(s.dropna(),s[-1])

# %%
cached = list_cached_symbols()
for info in cached:
    print(f"Symbol: {info['symbol']}")
    print(f"  Date Range: {info['date_range']}")
    print(f"  Records: {info['records']}")
    print(f"  Last Updated: {info['last_update']}")
    print(f"  File Size: {info['file_size']}")
# Out:
# Symbol: AAPL
#   Date Range: 2022-01-03 to 2024-01-30
#   Records: 521
#   Last Updated: 2025-05-30 16:36:41.351814
#   File Size: 25.8 KB

# %%
data2 = downloader("AAPL", "2023-06-01", "2025-05-31")
# Out:
# Processing data request for AAPL from 2023-06-01 to 2025-05-31...
# Found cached data for AAPL (last updated: 2025-05-31 20:01:03)
# Fetching missing data for AAPL: 2025-05-30 to 2025-05-31
# [*********************100%***********************]  1 of 1 completed
# Data download complete for AAPL. Shape: (501, 5)

# %%
# In main execution block
#stock_data = download_and_calculate_volatility(symbol, start_date, end_date)
#stock='DAL'#'603299.SS'
# Enhanced multi-stock comparison
#symbols = [stock]#['603100.SS']#['9979.HK']#['TSLA','AVGO']#['PEP','MRK','BMY','TSLA']#['PFE','DAL','OXY']#['AAPL', 'GOOGL', 'MSFT', 'TSLA']
comparison_data = {}

window = 20
res_dict=dict()
p_val=dict()



for stock in symbols:
    try:
        data =  downloader(stock, start_date,end_date)
        data['GK_Volatility'] = garman_klass_volatility(data, window)
        data['YZ_Volatility'] = yang_zhang_volatility(data, window)
        #plot_volatility_comparison(data, stock)
        #larger_proportion(res_dict[stock]['YZ_Volatility'].dropna(),0.5)
        # comparison_data[stock] = {
        #     'GK_Mean': data['GK_Volatility'].mean(),
        #     'YZ_Mean': data['YZ_Volatility'].mean(),
        #     'Volatility_Ratio': data['YZ_Volatility'].mean() / data['GK_Volatility'].mean()
        # }
        res_dict[stock]=data
    except Exception as e:
        print(f"Error processing {stock}: {e}")

for stock,data in res_dict.items():
    p_val[stock]={"YZ-pval":latest_pval(data['YZ_Volatility']),"GK-pval":latest_pval(data['GK_Volatility'])}
    print('{}: YZ-pval: {:.3f},  GK-pval: {:.3f}'.format(stock,p_val[stock]["YZ-pval"], p_val[stock]["GK-pval"]))
# comparison_df = pd.DataFrame(comparison_data).T
# print("\nMulti-Stock Volatility Analysis:")
# print(comparison_df.round(4))
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# Processing data request for AAPL from 2007-01-01 to 2025-06-03...
# Found cached data for AAPL (last updated: 2025-06-02 09:55:43)
# Fetching missing data for AAPL: 2007-01-01 to 2007-01-02
# Fetching missing data for AAPL: 2025-05-31 to 2025-06-03
# [*********************100%***********************]  1 of 1 completed
# Data download complete for AAPL. Shape: (4633, 5)
# Processing data request for PYPL from 2007-01-01 to 2025-06-03...
# Found cached data for PYPL (last updated: 2025-06-02 14:57:55)
# Fetching missing data for PYPL: 2007-01-01 to 2015-07-05
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['PYPL']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2015-07-05) (Yahoo error = "Data doesn\'t exist for startDate = 1167627600, endDate = 1436068800")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['GOOGL']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# Fetching missing data for PYPL: 2025-05-31 to 2025-06-03
# Data download complete for PYPL. Shape: (2493, 5)
# Processing data request for GOOGL from 2007-01-01 to 2025-06-03...
# Found cached data for GOOGL (last updated: 2025-06-02 09:55:44)
# Fetching missing data for GOOGL: 2007-01-01 to 2007-01-02
# Fetching missing data for GOOGL: 2025-05-31 to 2025-06-03
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QCOM']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# Data download complete for GOOGL. Shape: (4633, 5)
# Processing data request for QCOM from 2007-01-01 to 2025-06-03...
# Found cached data for QCOM (last updated: 2025-06-02 09:55:44)
# Fetching missing data for QCOM: 2007-01-01 to 2007-01-02
# Fetching missing data for QCOM: 2025-05-31 to 2025-06-03
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MTCH']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# Data download complete for QCOM. Shape: (4633, 5)
# Processing data request for MTCH from 2007-01-01 to 2025-06-03...
# Found cached data for MTCH (last updated: 2025-06-02 09:55:44)
# Fetching missing data for MTCH: 2007-01-01 to 2007-01-02
# Fetching missing data for MTCH: 2025-05-31 to 2025-06-03
# [*********************100%***********************]  1 of 1 completed
# Data download complete for MTCH. Shape: (4633, 5)
# Processing data request for DOW from 2007-01-01 to 2025-06-03...
# Found cached data for DOW (last updated: 2025-06-02 09:55:44)
# Fetching missing data for DOW: 2007-01-01 to 2019-03-19
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOW']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2019-03-19) (Yahoo error = "Data doesn\'t exist for startDate = 1167627600, endDate = 1552968000")')
# [*********************100%***********************]  1 of 1 completed
# Fetching missing data for DOW: 2025-05-31 to 2025-06-03
# Data download complete for DOW. Shape: (1560, 5)
# Processing data request for XOM from 2007-01-01 to 2025-06-03...
# Found cached data for XOM (last updated: 2025-06-02 09:55:45)
# Fetching missing data for XOM: 2007-01-01 to 2007-01-02
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['XOM']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# Fetching missing data for XOM: 2025-05-31 to 2025-06-03
# [*********************100%***********************]  1 of 1 completed
# Data download complete for XOM. Shape: (4633, 5)
# Processing data request for OXY from 2007-01-01 to 2025-06-03...
# Found cached data for OXY (last updated: 2025-06-02 09:55:45)
# Fetching missing data for OXY: 2007-01-01 to 2007-01-02
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['OXY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# [*********************100%***********************]  1 of 1 completed
# Fetching missing data for OXY: 2025-05-31 to 2025-06-03
# Data download complete for OXY. Shape: (4633, 5)
# Processing data request for CVX from 2007-01-01 to 2025-06-03...
# Found cached data for CVX (last updated: 2025-06-02 09:55:46)
# Fetching missing data for CVX: 2007-01-01 to 2007-01-02
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['CVX']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# [*********************100%***********************]  1 of 1 completed
# Fetching missing data for CVX: 2025-05-31 to 2025-06-03
# Data download complete for CVX. Shape: (4633, 5)
# Processing data request for SLB from 2007-01-01 to 2025-06-03...
# Found cached data for SLB (last updated: 2025-06-02 09:55:46)
# Fetching missing data for SLB: 2007-01-01 to 2007-01-02
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SLB']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# Fetching missing data for SLB: 2025-05-31 to 2025-06-03
# [*********************100%***********************]  1 of 1 completed
# Data download complete for SLB. Shape: (4633, 5)
# Processing data request for SU from 2007-01-01 to 2025-06-03...
# Found cached data for SU (last updated: 2025-06-02 09:55:46)
# Fetching missing data for SU: 2007-01-01 to 2007-01-02
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SU']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# [*********************100%***********************]  1 of 1 completed
# Fetching missing data for SU: 2025-05-31 to 2025-06-03
# Data download complete for SU. Shape: (4633, 5)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['TGT']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['TGT']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-03 -> 2025-06-03)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['UPS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# Processing data request for TGT from 2007-01-01 to 2025-06-03...
# Found cached data for TGT (last updated: 2025-06-04 15:48:15)
# Fetching missing data for TGT: 2007-01-01 to 2007-01-02
# Fetching missing data for TGT: 2025-06-03 to 2025-06-03
# Data download complete for TGT. Shape: (4633, 5)
# Processing data request for UPS from 2007-01-01 to 2025-06-03...
# Found cached data for UPS (last updated: 2025-06-02 09:55:47)
# Fetching missing data for UPS: 2007-01-01 to 2007-01-02
# Fetching missing data for UPS: 2025-05-31 to 2025-06-03
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NEE']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# Data download complete for UPS. Shape: (4633, 5)
# Processing data request for NEE from 2007-01-01 to 2025-06-03...
# Found cached data for NEE (last updated: 2025-06-02 09:55:47)
# Fetching missing data for NEE: 2007-01-01 to 2007-01-02
# Fetching missing data for NEE: 2025-05-31 to 2025-06-03
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['PEP']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# Data download complete for NEE. Shape: (4633, 5)
# Processing data request for PEP from 2007-01-01 to 2025-06-03...
# Found cached data for PEP (last updated: 2025-06-02 09:55:48)
# Fetching missing data for PEP: 2007-01-01 to 2007-01-02
# Fetching missing data for PEP: 2025-05-31 to 2025-06-03
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AZN']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# Data download complete for PEP. Shape: (4633, 5)
# Processing data request for AZN from 2007-01-01 to 2025-06-03...
# Found cached data for AZN (last updated: 2025-06-03 15:28:30)
# Fetching missing data for AZN: 2007-01-01 to 2007-01-02
# Fetching missing data for AZN: 2025-06-03 to 2025-06-03
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AZN']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-03 -> 2025-06-03)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['PFE']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# Data download complete for AZN. Shape: (4633, 5)
# Processing data request for PFE from 2007-01-01 to 2025-06-03...
# Found cached data for PFE (last updated: 2025-06-03 15:11:50)
# Fetching missing data for PFE: 2007-01-01 to 2007-01-02
# Fetching missing data for PFE: 2025-06-03 to 2025-06-03
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['PFE']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-03 -> 2025-06-03)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MRK']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# Data download complete for PFE. Shape: (4633, 5)
# Processing data request for MRK from 2007-01-01 to 2025-06-03...
# Found cached data for MRK (last updated: 2025-06-02 09:55:48)
# Fetching missing data for MRK: 2007-01-01 to 2007-01-02
# Fetching missing data for MRK: 2025-05-31 to 2025-06-03
# [*********************100%***********************]  1 of 1 completed
# Data download complete for MRK. Shape: (4633, 5)
# Processing data request for BMY from 2007-01-01 to 2025-06-03...
# Found cached data for BMY (last updated: 2025-06-02 14:56:01)
# Fetching missing data for BMY: 2007-01-01 to 2007-01-02
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BMY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# [*********************100%***********************]  1 of 1 completed
# Fetching missing data for BMY: 2025-05-31 to 2025-06-03
# Data download complete for BMY. Shape: (4633, 5)
# Processing data request for UNH from 2007-01-01 to 2025-06-03...
# Found cached data for UNH (last updated: 2025-06-02 09:55:49)
# Fetching missing data for UNH: 2007-01-01 to 2007-01-02
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['UNH']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# [*********************100%***********************]  1 of 1 completed
# Fetching missing data for UNH: 2025-05-31 to 2025-06-03
# Data download complete for UNH. Shape: (4633, 5)
# Processing data request for VALE from 2007-01-01 to 2025-06-03...
# Found cached data for VALE (last updated: 2025-06-02 09:55:49)
# Fetching missing data for VALE: 2007-01-01 to 2007-01-02
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['VALE']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# Fetching missing data for VALE: 2025-05-31 to 2025-06-03
# [*********************100%***********************]  1 of 1 completed
# Data download complete for VALE. Shape: (4633, 5)
# Processing data request for RIO from 2007-01-01 to 2025-06-03...
# Found cached data for RIO (last updated: 2025-06-03 15:09:09)
# Fetching missing data for RIO: 2007-01-01 to 2007-01-02
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['RIO']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['RIO']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-06-03 -> 2025-06-03)')
# Fetching missing data for RIO: 2025-06-03 to 2025-06-03
# Data download complete for RIO. Shape: (4633, 5)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['JD']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2014-05-21) (Yahoo error = "Data doesn\'t exist for startDate = 1167627600, endDate = 1400644800")')
# Processing data request for JD from 2007-01-01 to 2025-06-03...
# Found cached data for JD (last updated: 2025-06-02 09:55:50)
# Fetching missing data for JD: 2007-01-01 to 2014-05-21
# [*********************100%***********************]  1 of 1 completed
# Fetching missing data for JD: 2025-05-31 to 2025-06-03
# Data download complete for JD. Shape: (2774, 5)
# Processing data request for TSLA from 2007-01-01 to 2025-06-03...
# Found cached data for TSLA (last updated: 2025-06-02 09:55:50)
# Fetching missing data for TSLA: 2007-01-01 to 2010-06-28
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['TSLA']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2010-06-28) (Yahoo error = "Data doesn\'t exist for startDate = 1167627600, endDate = 1277697600")')
# [*********************100%***********************]  1 of 1 completed
# Fetching missing data for TSLA: 2025-05-31 to 2025-06-03
# Data download complete for TSLA. Shape: (3755, 5)
# Processing data request for AVGO from 2007-01-01 to 2025-06-03...
# Found cached data for AVGO (last updated: 2025-06-02 09:55:51)
# Fetching missing data for AVGO: 2007-01-01 to 2009-08-05
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AVGO']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2009-08-05) (Yahoo error = "Data doesn\'t exist for startDate = 1167627600, endDate = 1249444800")')
# [*********************100%***********************]  1 of 1 completed
# Fetching missing data for AVGO: 2025-05-31 to 2025-06-03
# Data download complete for AVGO. Shape: (3980, 5)
# Processing data request for TLT from 2007-01-01 to 2025-06-03...
# Found cached data for TLT (last updated: 2025-06-02 09:55:51)
# Fetching missing data for TLT: 2007-01-01 to 2007-01-02
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['TLT']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# [*********************100%***********************]  1 of 1 completed
# Fetching missing data for TLT: 2025-05-31 to 2025-06-03
# Data download complete for TLT. Shape: (4633, 5)
# Processing data request for IEF from 2007-01-01 to 2025-06-03...
# Found cached data for IEF (last updated: 2025-06-02 09:55:51)
# Fetching missing data for IEF: 2007-01-01 to 2007-01-02
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IEF']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# [*********************100%***********************]  1 of 1 completed
# Fetching missing data for IEF: 2025-05-31 to 2025-06-03
# Data download complete for IEF. Shape: (4633, 5)
# Processing data request for DAL from 2007-01-01 to 2025-06-03...
# Found cached data for DAL (last updated: 2025-06-02 14:41:10)
# Fetching missing data for DAL: 2007-01-01 to 2007-05-02
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DAL']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-05-02) (Yahoo error = "Data doesn\'t exist for startDate = 1167627600, endDate = 1178078400")')
# [*********************100%***********************]  1 of 1 completed
# Fetching missing data for DAL: 2025-05-31 to 2025-06-03
# Data download complete for DAL. Shape: (4550, 5)
# Processing data request for NKE from 2007-01-01 to 2025-06-03...
# Found cached data for NKE (last updated: 2025-06-02 09:55:52)
# Fetching missing data for NKE: 2007-01-01 to 2007-01-02
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NKE']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# [*********************100%***********************]  1 of 1 completed
# /var/folders/_q/zvg1j91x7sx_8_rt3f62v0ph0000gn/T/ipykernel_56405/3330865663.py:27: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   latest_pval=lambda s: larger_proportion(s.dropna(),s[-1])
# Fetching missing data for NKE: 2025-05-31 to 2025-06-03
# Data download complete for NKE. Shape: (4633, 5)
# AAPL: YZ-pval: 0.183,  GK-pval: 0.406
# PYPL: YZ-pval: 0.628,  GK-pval: 0.816
# GOOGL: YZ-pval: 0.135,  GK-pval: 0.074
# QCOM: YZ-pval: 0.341,  GK-pval: 0.551
# MTCH: YZ-pval: 0.449,  GK-pval: 0.443
# DOW: YZ-pval: 0.101,  GK-pval: 0.353
# XOM: YZ-pval: 0.429,  GK-pval: 0.569
# OXY: YZ-pval: 0.337,  GK-pval: 0.519
# CVX: YZ-pval: 0.437,  GK-pval: 0.617
# SLB: YZ-pval: 0.436,  GK-pval: 0.670
# SU: YZ-pval: 0.541,  GK-pval: 0.650
# TGT: YZ-pval: 0.119,  GK-pval: 0.233
# UPS: YZ-pval: 0.263,  GK-pval: 0.500
# NEE: YZ-pval: 0.076,  GK-pval: 0.070
# PEP: YZ-pval: 0.512,  GK-pval: 0.439
# AZN: YZ-pval: 0.388,  GK-pval: 0.338
# PFE: YZ-pval: 0.457,  GK-pval: 0.397
# MRK: YZ-pval: 0.135,  GK-pval: 0.142
# BMY: YZ-pval: 0.251,  GK-pval: 0.177
# UNH: YZ-pval: 0.021,  GK-pval: 0.045
# VALE: YZ-pval: 0.959,  GK-pval: 0.988
# RIO: YZ-pval: 0.946,  GK-pval: 0.946
# JD: YZ-pval: 0.654,  GK-pval: 0.868
# TSLA: YZ-pval: 0.380,  GK-pval: 0.565
# AVGO: YZ-pval: 0.197,  GK-pval: 0.359
# TLT: YZ-pval: 0.418,  GK-pval: 0.545
# IEF: YZ-pval: 0.383,  GK-pval: 0.522
# DAL: YZ-pval: 0.297,  GK-pval: 0.424
# NKE: YZ-pval: 0.168,  GK-pval: 0.343

# %%
# Define trading days for different periods
# Approximate trading days (assuming ~252 trading days per year)
periods = {
    "3M": 63,    # 3 months ≈ 63 trading days
    "6M": 126,   # 6 months ≈ 126 trading days
    "1Y": 252,   # 1 year ≈ 252 trading days
    "3Y": 756,   # 3 years ≈ 756 trading days
    "5Y": 1260,  # 5 years ≈ 1260 trading days
    "10Y": 2520  # 10 years ≈ 2520 trading days
}

# Option 1: Analyze all periods for each stock
for stock, data in res_dict.items():
    #print(f"\n{stock}:")
    p_val[stock] = {}
    
    for period_name, days in periods.items():
        # Slice the data to get the last N trading days
        recent_data = data.tail(days)
        
        # Calculate p-values for the restricted period
        yz_pval = latest_pval(recent_data['YZ_Volatility'])
        #gk_pval = latest_pval(recent_data['GK_Volatility'])
        
        p_val[stock][f"{period_name}_YZ-pval"] = yz_pval
        #p_val[stock][f"{period_name}_GK-pval"] = gk_pval
        
        #print(f'  {period_name}: YZ-pval: {yz_pval:.3f}, GK-pval: {gk_pval:.3f}')

# Option 2: Analyze a specific period only (e.g., last 1 year)
# selected_period = "1Y"  # Change this to desired period
# selected_days = periods[selected_period]

# print(f"\n=== Analysis for Last {selected_period} ===")
# p_val_period = {}

# for stock, data in res_dict.items():
#     # Restrict to selected period
#     recent_data = data.tail(selected_days)
    
#     p_val_period[stock] = {
#         "YZ-pval": latest_pval(recent_data['YZ_Volatility']),
#         "GK-pval": latest_pval(recent_data['GK_Volatility'])
#     }
    
#     print('{}: YZ-pval: {:.3f}, GK-pval: {:.3f}'.format(
#         stock, 
#         p_val_period[stock]["YZ-pval"], 
#         p_val_period[stock]["GK-pval"]
#     ))

# # Option 3: Function to get analysis for any specific period
# def analyze_period(res_dict, period_days, period_name=""):
#     """Analyze volatility p-values for a specific time period"""
#     results = {}
    
#     if period_name:
#         print(f"\n=== Analysis for {period_name} ===")
    
#     for stock, data in res_dict.items():
#         # Ensure we don't try to slice more data than available
#         actual_days = min(period_days, len(data))
#         recent_data = data.tail(actual_days)
        
#         results[stock] = {
#             "YZ-pval": latest_pval(recent_data['YZ_Volatility']),
#             "GK-pval": latest_pval(recent_data['GK_Volatility']),
#             #"data_points": len(recent_data)
#         }
        
#         print('{}: YZ-pval: {:.3f}, GK-pval: {:.3f} (n={})'.format(
#             stock, 
#             results[stock]["YZ-pval"], 
#             results[stock]["GK-pval"],
#             len(recent_data)
#             #results[stock]["data_points"]
#         ))
    
#     return results

# # Example usage of the function
# results_1y = analyze_period(res_dict, periods["1Y"], "Last 1 Year")
# results_3m = analyze_period(res_dict, periods["6M"], "Last 3 Months")
# Out:
# /var/folders/_q/zvg1j91x7sx_8_rt3f62v0ph0000gn/T/ipykernel_68520/3330865663.py:27: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   latest_pval=lambda s: larger_proportion(s.dropna(),s[-1])

# %%
p_val['XOM']
# Out:
# {'3M_YZ-pval': 0.9206349206349206,
#  '6M_YZ-pval': 0.4603174603174603,
#  '1Y_YZ-pval': 0.3253968253968254,
#  '3Y_YZ-pval': 0.49206349206349204,
#  '5Y_YZ-pval': 0.6674603174603174,
#  '10Y_YZ-pval': 0.43214285714285716}

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Convert the data into a DataFrame
df = pd.DataFrame(p_val).T

# Apply -log10 transformation to the p-values
#df_log = -np.log10(df)
df_log=df
# Plotting the transformed values
fig, ax = plt.subplots(figsize=(14, 8))
df_log.plot(kind='bar', ax=ax)

# Adding labels and title
plt.title("P-values for Various Stocks")#-Log10 Transformed 
plt.xlabel("Stocks")
plt.ylabel("-Log10(P-values)")
plt.xticks(rotation=45, ha='right')
plt.legend(title='P-value Type')
plt.tight_layout()

# Show plot
plt.show()

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

class KDJCrossoverDetector:
    def __init__(self, data,n=9, m1=3, m2=3):
        """
        Initialize KDJ Crossover Detector
        
        Parameters:
        symbol: Stock symbol (e.g., 'AAPL', 'TSLA')
        period: Data period ('1y', '2y', '5y', 'max', etc.)
        n: Period for %K calculation (default: 9)
        m1: Smoothing period for %K (default: 3)
        m2: Smoothing period for %D (default: 3)
        """
        self.n = n
        self.m1 = m1
        self.m2 = m2
        self.data = data
        self.kdj_data = None
        self.symbol=data.columns[0][1]
    
    def calculate_kdj(self):
        """Calculate KDJ indicator"""
        if self.data is None:
            print("No data available. Please fetch data first.")
            return None
        
        df = self.data.copy()
        
        # Ensure all price columns are numeric
        # for col in ['High', 'Low', 'Close']:
        #     df[col] = pd.to_numeric(df[col], errors='coerce')
        
        # Remove any rows with NaN values in price data
        df.columns=[i[0] for i in df.columns]
        #print(df)
        #df = df.dropna(subset=['High', 'Low', 'Close'])
        
        # Calculate RSV (Raw Stochastic Value)
        low_n = df['Low'].rolling(window=self.n).min()
        high_n = df['High'].rolling(window=self.n).max()
        
        # Calculate RSV with proper handling of division by zero
        denominator = high_n - low_n
        rsv = np.where(denominator != 0, 100 * (df['Close'] - low_n) / denominator, 50)
        rsv = pd.Series(rsv, index=df.index)
        
        # Initialize K, D, J series
        k_values = []
        d_values = []
        j_values = []
        
        # Initial values
        k_prev = 50.0  # Starting value for K
        d_prev = 50.0  # Starting value for D
        
        for i, rsv_val in enumerate(rsv):
            # Ensure rsv_val is numeric
            if pd.isna(rsv_val) or not isinstance(rsv_val, (int, float)):
                rsv_val = 50.0
            else:
                rsv_val = float(rsv_val)
            
            # Calculate K: K = (2/3) * K_prev + (1/3) * RSV
            k_curr = (2.0/3.0) * float(k_prev) + (1.0/3.0) * rsv_val
            
            # Calculate D: D = (2/3) * D_prev + (1/3) * K
            d_curr = (2.0/3.0) * float(d_prev) + (1.0/3.0) * k_curr
            
            # Calculate J: J = 3*K - 2*D
            j_curr = 3.0 * k_curr - 2.0 * d_curr
            
            k_values.append(k_curr)
            d_values.append(d_curr)
            j_values.append(j_curr)
            
            k_prev = k_curr
            d_prev = d_curr
        
        # Add KDJ to dataframe
        df['K'] = k_values
        df['D'] = d_values
        df['J'] = j_values
        df['RSV'] = rsv
        
        self.kdj_data = df
        return df
    
    def detect_crossovers(self):
        """Detect KDJ crossover signals"""
        if self.kdj_data is None:
            print("KDJ data not calculated. Please calculate KDJ first.")
            return None
        
        df = self.kdj_data.copy()
        
        # Calculate crossover signals
        df['K_cross_D'] = np.where(
            (df['K'].shift(1) <= df['D'].shift(1)) & (df['K'] > df['D']), 1,
            np.where((df['K'].shift(1) >= df['D'].shift(1)) & (df['K'] < df['D']), -1, 0)
        )
        
        df['K_cross_J'] = np.where(
            (df['K'].shift(1) <= df['J'].shift(1)) & (df['K'] > df['J']), 1,
            np.where((df['K'].shift(1) >= df['J'].shift(1)) & (df['K'] < df['J']), -1, 0)
        )
        
        df['D_cross_J'] = np.where(
            (df['D'].shift(1) <= df['J'].shift(1)) & (df['D'] > df['J']), 1,
            np.where((df['D'].shift(1) >= df['J'].shift(1)) & (df['D'] < df['J']), -1, 0)
        )
        
        # Golden Cross (bullish): K crosses above D
        df['Golden_Cross'] = (df['K_cross_D'] == 1)
        
        # Death Cross (bearish): K crosses below D
        df['Death_Cross'] = (df['K_cross_D'] == -1)
        
        # Additional signals
        df['Bullish_Signal'] = (
            (df['K_cross_D'] == 1) | 
            ((df['K'] > df['D']) & (df['J'] > df['K']) & (df['K'] > 20))
        )
        
        df['Bearish_Signal'] = (
            (df['K_cross_D'] == -1) | 
            ((df['K'] < df['D']) & (df['J'] < df['K']) & (df['K'] < 80))
        )
        
        self.kdj_data = df
        return df

    def get_crossover_summary(self, days=30):
        """Get summary of recent crossover signals"""
        if self.kdj_data is None:
            return "No KDJ data available"
        
        recent_data = self.kdj_data.tail(days)
        
        golden_crosses = recent_data[recent_data['Golden_Cross']].index.tolist()
        death_crosses = recent_data[recent_data['Death_Cross']].index.tolist()
        
        summary = f"\n=== KDJ Crossover Summary for {self.symbol} (Last {days} days) ===\n"
        
        if golden_crosses:
            summary += f"Golden Crosses (Bullish): {len(golden_crosses)}\n"
            for date in golden_crosses[-3:]:  # Show last 3
                k_val = recent_data.loc[date, 'K']
                d_val = recent_data.loc[date, 'D']
                summary += f"  - {date.strftime('%Y-%m-%d')}: K({k_val:.2f}) crossed above D({d_val:.2f})\n"
        
        if death_crosses:
            summary += f"Death Crosses (Bearish): {len(death_crosses)}\n"
            for date in death_crosses[-3:]:  # Show last 3
                k_val = recent_data.loc[date, 'K']
                d_val = recent_data.loc[date, 'D']
                summary += f"  - {date.strftime('%Y-%m-%d')}: K({k_val:.2f}) crossed below D({d_val:.2f})\n"
        return summary
        
        # Current values
    def signalling(self,parameter=2):
        latest = self.kdj_data.iloc[-1]
        summary=''
        summary += f"\nCurrent Values ({latest.name.strftime('%Y-%m-%d')}):\n"
        summary += f"  K: {latest['K']:.2f}\n"
        summary += f"  D: {latest['D']:.2f}\n"
        summary += f"  J: {latest['J']:.2f}\n"
        summary += f"  Price: ${latest['Close']:.2f}\n"
        
        # Check if K, D, J values are very close (within 1 point)
        k_val = latest['K']
        d_val = latest['D']
        j_val = latest['J']
        
        kd_diff = abs(k_val - d_val)
        kj_diff = abs(k_val - j_val)
        dj_diff = abs(d_val - j_val)
        
        summary=None
        if (kd_diff <= parameter) or (kj_diff <= parameter) or (dj_diff <= parameter):
            summary =f"\n⚠️  WARNING: KDJ values are converging!\n"
            summary += f"   K-D difference: {kd_diff:.2f}\n"
            summary += f"   K-J difference: {kj_diff:.2f}\n"
            summary += f"   D-J difference: {dj_diff:.2f}\n"
            summary += f"   This may indicate an upcoming crossover or period of indecision.\n"
        
        return summary
    
    def plot_kdj(self, days=60):
        """Plot KDJ indicator with crossover signals"""
        if self.kdj_data is None:
            print("No KDJ data to plot")
            return
        
        recent_data = self.kdj_data.tail(days)
        
        fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10), 
                                       gridspec_kw={'height_ratios': [2, 1]})
        
        # Plot price and signals
        ax1.plot(recent_data.index, recent_data['Close'], label='Close Price', linewidth=2)
        
        # Mark crossover points
        golden_crosses = recent_data[recent_data['Golden_Cross']]
        death_crosses = recent_data[recent_data['Death_Cross']]
        
        if not golden_crosses.empty:
            ax1.scatter(golden_crosses.index, golden_crosses['Close'], 
                       color='green', marker='^', s=100, label='Golden Cross', zorder=5)
        
        if not death_crosses.empty:
            ax1.scatter(death_crosses.index, death_crosses['Close'], 
                       color='red', marker='v', s=100, label='Death Cross', zorder=5)
        
        ax1.set_title(f'{self.symbol} Price with KDJ Crossover Signals')
        ax1.set_ylabel('Price ($)')
        ax1.legend()
        ax1.grid(True, alpha=0.3)
        
        # Plot KDJ lines
        ax2.plot(recent_data.index, recent_data['K'], label='K', color='blue', linewidth=2)
        ax2.plot(recent_data.index, recent_data['D'], label='D', color='red', linewidth=2)
        ax2.plot(recent_data.index, recent_data['J'], label='J', color='green', linewidth=1, alpha=0.7)
        
        # Add horizontal lines for overbought/oversold levels
        ax2.axhline(y=80, color='red', linestyle='--', alpha=0.5, label='Overbought (80)')
        ax2.axhline(y=20, color='green', linestyle='--', alpha=0.5, label='Oversold (20)')
        ax2.axhline(y=50, color='gray', linestyle='-', alpha=0.3)
        
        ax2.set_title('KDJ Indicator')
        ax2.set_ylabel('KDJ Values')
        ax2.set_xlabel('Date')
        ax2.legend()
        ax2.grid(True, alpha=0.3)
        ax2.set_ylim(0, 100)
        
        plt.tight_layout()
        plt.show()
    
    def run_analysis(self,verbose=False):
        """Run complete KDJ analysis"""
        #print(f"Starting KDJ analysis for {self.data.columns[0][1]}...")
        
        # Fetch data
        # if not self.fetch_data():
        #     return
        
        # Calculate KDJ
        self.calculate_kdj()
        print("KDJ indicator calculated successfully")
        
        # Detect crossovers
        self.detect_crossovers()
        
        if verbose:
            #Print summary
            print(self.get_crossover_summary())

        signal=self.signalling()
        if (signal is not None) or verbose:
            print("Crossover signals detected")
            print(signal)
        # Plot results
            self.plot_kdj()
            return signal
        #print(self.get_crossover_summary())

# def main():
#     """Example usage"""
#     # Example 1: Analyze Apple stock
#     print("=== KDJ Crossover Analysis ===")
    
#     detector = KDJCrossoverDetector(data2)
#     detector.run_analysis()
    
    # # Example 2: Quick analysis of multiple stocks
    # symbols = ['TSLA', 'GOOGL', 'MSFT']
    
    # print("\n" + "="*50)
    # print("QUICK ANALYSIS OF MULTIPLE STOCKS")
    # print("="*50)
    
    # for symbol in symbols:
    #     print(f"\n--- {symbol} ---")
    #     detector = KDJCrossoverDetector(symbol, period='3mo')
    #     if detector.fetch_data():
    #         detector.calculate_kdj()
    #         detector.detect_crossovers()
    #         print(detector.get_crossover_summary(days=10))

# if __name__ == "__main__":
#     main()

# %%
stock='PFE'
data =  downloader(stock, start_date,end_date)
detector = KDJCrossoverDetector(data)
signal=detector.run_analysis(verbose=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['PFE']: YFPricesMissingError('possibly delisted; no price data found  (1d 2007-01-01 -> 2007-01-02)')
# [*********************100%***********************]  1 of 1 completed
# Processing data request for PFE from 2007-01-01 to 2025-05-31...
# Found cached data for PFE (last updated: 2025-05-31 21:52:38)
# Fetching missing data for PFE: 2007-01-01 to 2007-01-02
# Fetching missing data for PFE: 2025-05-31 to 2025-05-31
# Data download complete for PFE. Shape: (4632, 5)
# KDJ indicator calculated successfully
#
# === KDJ Crossover Summary for PFE (Last 30 days) ===
# Golden Crosses (Bullish): 1
#   - 2025-05-16: K(39.47) crossed above D(36.93)
# Death Crosses (Bearish): 1
#   - 2025-05-06: K(64.45) crossed below D(75.64)
#
# Crossover signals detected
# None

# %%
signals=dict()
for stock in uk_symbols:
    
    data =  downloader(stock, start_date,end_date)
    detector = KDJCrossoverDetector(data)
    signal=detector.run_analysis()
    if signal is not None:
        signals[stock]=signal
# Out:
# Processing data request for UTG.L from 2007-01-01 to 2025-05-31...
# No cached data found for UTG.L - downloading all data...
# [*********************100%***********************]  1 of 1 completed
# Data download complete for UTG.L. Shape: (4651, 5)
# KDJ indicator calculated successfully
# Processing data request for DOM.L from 2007-01-01 to 2025-05-31...
# No cached data found for DOM.L - downloading all data...
# [*********************100%***********************]  1 of 1 completed
# Data download complete for DOM.L. Shape: (4651, 5)
# KDJ indicator calculated successfully
# Processing data request for GLEN.L from 2007-01-01 to 2025-05-31...
# No cached data found for GLEN.L - downloading all data...
# [*********************100%***********************]  1 of 1 completed
# Data download complete for GLEN.L. Shape: (3543, 5)
# KDJ indicator calculated successfully
# Processing data request for DGE.L from 2007-01-01 to 2025-05-31...
# No cached data found for DGE.L - downloading all data...
# [*********************100%***********************]  1 of 1 completed
# Data download complete for DGE.L. Shape: (4650, 5)
# KDJ indicator calculated successfully
# Processing data request for POLR.L from 2007-01-01 to 2025-05-31...
# No cached data found for POLR.L - downloading all data...
# [*********************100%***********************]  1 of 1 completed
# Data download complete for POLR.L. Shape: (4626, 5)
# KDJ indicator calculated successfully
# Crossover signals detected
#
# ⚠️  WARNING: KDJ values are converging!
#    K-D difference: 0.42
#    K-J difference: 0.84
#    D-J difference: 1.26
#    This may indicate an upcoming crossover or period of indecision.
# Processing data request for IPX.L from 2007-01-01 to 2025-05-31...
# No cached data found for IPX.L - downloading all data...
# [*********************100%***********************]  1 of 1 completed
# Data download complete for IPX.L. Shape: (4651, 5)
# KDJ indicator calculated successfully
# Processing data request for WPP.L from 2007-01-01 to 2025-05-31...
# No cached data found for WPP.L - downloading all data...
# [*********************100%***********************]  1 of 1 completed
# Data download complete for WPP.L. Shape: (4650, 5)
# KDJ indicator calculated successfully
# Processing data request for SAFE.L from 2007-01-01 to 2025-05-31...
# No cached data found for SAFE.L - downloading all data...
# [*********************100%***********************]  1 of 1 completed
# Data download complete for SAFE.L. Shape: (4603, 5)
# KDJ indicator calculated successfully

# %%
signals
# Out:
# {'POLR.L': '\n⚠️  WARNING: KDJ values are converging!\n   K-D difference: 0.42\n   K-J difference: 0.84\n   D-J difference: 1.26\n   This may indicate an upcoming crossover or period of indecision.\n'}

# %%
data
# Out:
#                 Close       High        Low       Open    Volume  \
# Date
# 2007-01-03   9.634974   9.836217   9.550137   9.667529  17299200
# 2007-01-04   9.733624   9.763219   9.555071   9.634976  15085600
# 2007-01-05   9.749405   9.806621   9.637932   9.677391  14996800
# 2007-01-08   9.719813   9.765191   9.631030   9.716854  10109600
# 2007-01-09   9.841148   9.858905   9.703041   9.719811  15167200
# ...               ...        ...        ...        ...       ...
# 2025-05-15  62.400002  62.680000  60.419998  60.639999  14371100
# 2025-05-16  63.110001  63.750000  62.500000  62.500000  12950600
# 2025-05-19  62.080002  62.430000  61.759998  62.150002  15105300
# 2025-05-20  62.560001  63.189999  62.279999  62.500000  10771800
# 2025-05-21  59.980000  61.759998  59.880001  61.169998  17354700
#
#             GK_Volatility  YZ_Volatility
# Date
# 2007-01-03            NaN            NaN
# 2007-01-04            NaN            NaN
# 2007-01-05            NaN            NaN
# 2007-01-08            NaN            NaN
# 2007-01-09            NaN            NaN
# ...                   ...            ...
# 2025-05-15       0.287548       0.432305
# 2025-05-16       0.281116       0.428843
# 2025-05-19       0.252806       0.411476
# 2025-05-20       0.242664       0.405377
# 2025-05-21       0.234574       0.396442
#
# [4626 rows x 7 columns]

# %%
larger_proportion(res_dict['PFE']['YZ_Volatility'].dropna(),0.5)
# Out:
# 0.03430308293530178

# %%
import seaborn as sns
def validate_volatility_estimators(data, window=20, trading_periods=252):
    """
    Comprehensive validation of volatility estimators with multiple metrics.
    
    Parameters:
    data: DataFrame containing 'GK_Volatility' and 'YZ_Volatility'
    window: Lookback window for realized volatility calculation
    trading_periods: Annualization factor (default 252)
    
    Returns:
    pd.Series with validation metrics
    """
    # Calculate realized volatility benchmark
    realized_vol = data['Close'].pct_change().rolling(window).std() * np.sqrt(trading_periods)
    #return realized_vol
    metrics = {
        # Error metrics
        'GK vs Realized MAE': (data['GK_Volatility'] - realized_vol).abs().mean(),
        'YZ vs Realized MAE': (data['YZ_Volatility'] - realized_vol).abs().mean(),
        'GK vs Realized RMSE': np.sqrt(((data['GK_Volatility'] - realized_vol)**2).mean()),
        'YZ vs Realized RMSE': np.sqrt(((data['YZ_Volatility'] - realized_vol)**2).mean()),
        
        # Correlation analysis
        'GK-YZ Correlation': data['GK_Volatility'].corr(data['YZ_Volatility']),
        'GK-Realized Corr': data['GK_Volatility'].corr(realized_vol),
        'YZ-Realized Corr': data['YZ_Volatility'].corr(realized_vol),
        
        # Volatility ratio analysis
        'Avg YZ/GK Ratio': data['YZ_Volatility'].mean() / data['GK_Volatility'].mean(),
        'Max YZ/GK Ratio': (data['YZ_Volatility'] / data['GK_Volatility']).max(),
        'Min YZ/GK Ratio': (data['YZ_Volatility'] / data['GK_Volatility']).min()
    }
    
    return pd.Series(metrics).round(4)

def plot_volatility_analysis(data, symbol):
    """
    Enhanced visualization with four complementary views
    """
    fig = plt.figure(figsize=(16, 18))
    gs = fig.add_gridspec(4, 2)
    
    # Price and Volatility Timeline
    ax1 = fig.add_subplot(gs[0, :])
    ax1.plot(data['Close'], label='Price', color='#1f77b4')
    ax1.set_title(f'{symbol} Price Action', pad=20)
    ax1.set_ylabel('Price ($)', labelpad=15)
    ax1.grid(True, alpha=0.3)
    
    # Volatility Comparison
    ax2 = fig.add_subplot(gs[1, :])
    ax2.plot(data['GK_Volatility'], label='Garman-Klass', color='#2ca02c')
    ax2.plot(data['YZ_Volatility'], label='Yang-Zhang', color='#d62728')
    ax2.set_title('Volatility Estimators Comparison', pad=20)
    ax2.set_ylabel('Annualized Volatility', labelpad=15)
    ax2.legend()
    ax2.grid(True, alpha=0.3)
    
    # Estimator Difference Analysis
    ax3 = fig.add_subplot(gs[2, 0])
    diff = data['YZ_Volatility'] - data['GK_Volatility']
    sns.histplot(diff.dropna(), kde=True, color='#9467bd', ax=ax3)
    ax3.set_title('Distribution of YZ-GK Volatility Difference')
    ax3.set_xlabel('Volatility Difference')
    ax3.grid(True, alpha=0.3)
    
    # Error Metrics Radar Chart
    ax4 = fig.add_subplot(gs[2, 1], polar=True)
    metrics = validate_volatility_estimators(data)
    error_metrics = metrics[['GK vs Realized MAE', 'YZ vs Realized MAE', 
                            'GK vs Realized RMSE', 'YZ vs Realized RMSE']]
    
    categories = error_metrics.index.str.replace(' vs Realized ', '\n')
    values = error_metrics.values
    values = np.concatenate((values, [values[0]]))
    
    angles = np.linspace(0, 2*np.pi, len(categories), endpoint=False).tolist()
    angles += angles[:1]
    
    ax4.plot(angles, values, color='#ff7f0e', linewidth=2)
    ax4.fill(angles, values, color='#ff7f0e', alpha=0.25)
    ax4.set_xticks(angles[:-1])
    ax4.set_xticklabels(categories)
    ax4.set_title('Error Metrics Comparison', pad=30)
    
    # Correlation Matrix
    ax5 = fig.add_subplot(gs[3, :])
    corr_matrix = data[['GK_Volatility', 'YZ_Volatility']].join(
        realized_vol.rename('Realized_Vol')).corr()
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', ax=ax5,
                annot_kws={"size": 14}, cbar=False)
    ax5.set_title('Volatility Estimators Correlation Matrix', pad=20)
    
    plt.tight_layout()
    plt.show()

# %%
symbols = ['AAPL', 'GOOGL', 'MSFT', 'TSLA']
comparison_data = {}

for stock in symbols:
    # try:
    data = download_and_calculate_volatility(stock, start_date, end_date)

    plot_volatility_analysis(data,stock)
    # except Exception as e:
    #     print(f"Error processing {stock}: {e}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Downloading data for AAPL...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[93], line 8
#       4 for stock in symbols:
#       5     # try:
#       6     data = download_and_calculate_volatility(stock, start_date, end_date)
# ----> 8     plot_volatility_analysis(data,stock)
#       9     # except Exception as e:
#      10     #     print(f"Error processing {stock}: {e}")
#
# Cell In[92], line 70, in plot_volatility_analysis(data, symbol)
#      68 # Error Metrics Radar Chart
#      69 ax4 = fig.add_subplot(gs[2, 1], polar=True)
# ---> 70 metrics = validate_volatility_estimators(data)
#      71 error_metrics = metrics[['GK vs Realized MAE', 'YZ vs Realized MAE',
#      72                         'GK vs Realized RMSE', 'YZ vs Realized RMSE']]
#      74 categories = error_metrics.index.str.replace(' vs Realized ', '\n')
#
# Cell In[92], line 26, in validate_volatility_estimators(data, window, trading_periods)
#      15 realized_vol = data['Close'].pct_change().rolling(window).std() * np.sqrt(trading_periods)
#      16 #return realized_vol
#      17 metrics = {
#      18     # Error metrics
#      19     'GK vs Realized MAE': (data['GK_Volatility'] - realized_vol).abs().mean(),
#      20     'YZ vs Realized MAE': (data['YZ_Volatility'] - realized_vol).abs().mean(),
#      21     'GK vs Realized RMSE': np.sqrt(((data['GK_Volatility'] - realized_vol)**2).mean()),
#      22     'YZ vs Realized RMSE': np.sqrt(((data['YZ_Volatility'] - realized_vol)**2).mean()),
#      23
#      24     # Correlation analysis
#      25     'GK-YZ Correlation': data['GK_Volatility'].corr(data['YZ_Volatility']),
# ---> 26     'GK-Realized Corr': data['GK_Volatility'].corr(realized_vol),
#      27     'YZ-Realized Corr': data['YZ_Volatility'].corr(realized_vol),
#      28
#      29     # Volatility ratio analysis
#      30     'Avg YZ/GK Ratio': data['YZ_Volatility'].mean() / data['GK_Volatility'].mean(),
#      31     'Max YZ/GK Ratio': (data['YZ_Volatility'] / data['GK_Volatility']).max(),
#      32     'Min YZ/GK Ratio': (data['YZ_Volatility'] / data['GK_Volatility']).min()
#      33 }
#      35 return pd.Series(metrics).round(4)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:2977, in Series.corr(self, other, method, min_periods)
#    2974 other_values = other.to_numpy(dtype=float, na_value=np.nan, copy=False)
#    2976 if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2977     return nanops.nancorr(
#    2978         this_values, other_values, method=method, min_periods=min_periods
#    2979     )
#    2981 raise ValueError(
#    2982     "method must be either 'pearson', "
#    2983     "'spearman', 'kendall', or a callable, "
#    2984     f"'{method}' was supplied"
#    2985 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      81     raise TypeError(
#      82         f"reduction operation '{f_name}' not allowed for this dtype"
#      83     )
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#      91     if is_object_dtype(args[0]):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:1605, in nancorr(a, b, method, min_periods)
#    1603 valid = notna(a) & notna(b)
#    1604 if not valid.all():
# -> 1605     a = a[valid]
#    1606     b = b[valid]
#    1608 if len(a) < min_periods:
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %% [markdown]
# li=[]
# for i in range(1,2):
#     file_path="data/active_options_stocks/"+str(i)+"_Most Active Stock Options - TipRanks.com.html"
#     with open(file_path, 'r', encoding='utf-8') as file:
#         html_content = file.read()
#     soup = BeautifulSoup(html_content, 'html.parser')
#     table = soup.find('table', class_='screenerTable')
#
#     # Extract headers
#     headers = [th.get_text(strip=True) for th in table.thead.find_all('th')]
#
#     # Extract rows
#     rows = []
#     for row in table.tbody.find_all('tr', class_='rt-tr'):
#         cells = row.find_all('td', class_='rt-td')
#         row_data = [cell.get_text(strip=True) for cell in cells]
#         rows.append(row_data)
#
#     # Create DataFrame
#     df = pd.DataFrame(rows, columns=headers)
#     li.append(df)
# active_options_stocks=pd.concat(li)
# active_options_stocks.set_index('Symbol',drop=True,inplace=True)
