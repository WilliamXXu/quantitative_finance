# %%
from google.genai import types
from google import genai
import os
import time
import pandas as pd
import random
import yfinance as yf

import csv
import numpy as np
from scipy.stats import uniform, beta
nation_ending={'UK':'.L','US':''}

# %%
def gamma_param(mean, std):
    """
    Creates a gamma distribution with a specified mean (μ) and standard deviation (σ).

    Parameters:
        mean (float): Desired mean of the distribution (must be > 0).
        std (float): Desired standard deviation of the distribution (must be > 0).

    Returns:
        scipy.stats._distn_infrastructure.rv_frozen: A frozen gamma distribution object.

    Raises:
        ValueError: If mean or std is non-positive.
    """
    if mean <= 0 or std <= 0:
        raise ValueError("Mean and standard deviation must be positive.")

    # Calculate shape (alpha) and scale (theta) parameters
    alpha = (mean ** 2) / (std ** 2)  # Shape parameter (k or a)
    theta = (std ** 2) / mean          # Scale parameter

    # Create and return the gamma distribution
    return alpha,theta

# %%
def beta_param(mu,sigma2):
    a=mu*(mu*(1-mu)/sigma2 - 1)
    b = a*(1-mu)/mu
    return a,b

# %%
gamma_param(10,10)
# Out:
# (1.0, 10.0)

# %%
client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))
def summary(full_name,nation,client):
    question='Please summarise the business of '+nation+' company '+full_name+'. Return one sentence within 500 characters.'
    response = client.models.generate_content(
    model="gemini-2.0-flash", contents=question,config=types.GenerateContentConfig(
        tools=[types.Tool(
            google_search=types.GoogleSearchRetrieval
        )]
    )
)
    return response.text

# %%
annotated_list=pd.read_csv('data/sp500_annotation.csv',index_col=0)

# %%
annotated_list.copy(deep=True).iloc[374:,]
# Out:
#        Exchange                       Shortname  \
# Symbol
# FSLR        NMS               First Solar, Inc.
# BF-B        NYQ                Brown Forman Inc
# LDOS        NYQ           Leidos Holdings, Inc.
# CFG         NYQ  Citizens Financial Group, Inc.
# LH          NYQ           Labcorp Holdings Inc.
# ...         ...                             ...
# CZR         NMS     Caesars Entertainment, Inc.
# BWA         NYQ                 BorgWarner Inc.
# QRVO        NMS                     Qorvo, Inc.
# FMC         NYQ                 FMC Corporation
# AMTM        NYQ          Amentum Holdings, Inc.
#
#                               Longname              Sector  \
# Symbol
# FSLR                 First Solar, Inc.          Technology
# BF-B          Brown-Forman Corporation  Consumer Defensive
# LDOS             Leidos Holdings, Inc.          Technology
# CFG     Citizens Financial Group, Inc.  Financial Services
# LH               Labcorp Holdings Inc.          Healthcare
# ...                                ...                 ...
# CZR        Caesars Entertainment, Inc.   Consumer Cyclical
# BWA                    BorgWarner Inc.   Consumer Cyclical
# QRVO                       Qorvo, Inc.          Technology
# FMC                    FMC Corporation     Basic Materials
# AMTM            Amentum Holdings, Inc.         Industrials
#
#                                    Industry  Currentprice    Marketcap  \
# Symbol
# FSLR                                  Solar        182.39  19526307840
# BF-B    Beverages - Wineries & Distilleries         41.28  19369400320
# LDOS        Information Technology Services        144.81  19322431488
# CFG                        Banks - Regional         43.45  19148457984
# LH                   Diagnostics & Research        228.61  19120779264
# ...                                     ...           ...          ...
# CZR                       Resorts & Casinos         32.82   6973593600
# BWA                              Auto Parts         31.88   6972155904
# QRVO                         Semiconductors         70.85   6697217024
# FMC                     Agricultural Inputs         50.15   6260525568
# AMTM            Specialty Business Services         19.17   4664099328
#
#               Ebitda  Revenuegrowth          City State        Country  \
# Symbol
# FSLR    1.716966e+09          0.108         Tempe    AZ  United States
# BF-B    1.198000e+09         -0.084    Louisville    KY  United States
# LDOS    2.057000e+09          0.069        Reston    VA  United States
# CFG              NaN         -0.061    Providence    RI  United States
# LH      1.673500e+09          0.074    Burlington    NC  United States
# ...              ...            ...           ...   ...            ...
# CZR     3.668000e+09         -0.040          Reno    NV  United States
# BWA     1.882000e+09         -0.048  Auburn Hills    MI  United States
# QRVO    6.731300e+08         -0.052    Greensboro    NC  United States
# FMC     7.033000e+08          0.085  Philadelphia    PA  United States
# AMTM    4.330000e+08         -0.031     Chantilly    VA  United States
#
#         Fulltimeemployees                                Longbusinesssummary  \
# Symbol
# FSLR               6700.0  First Solar, Inc., a solar technology company,...
# BF-B               5700.0  Brown-Forman Corporation, together with its su...
# LDOS              47000.0  Leidos Holdings, Inc., together with its subsi...
# CFG               17329.0  Citizens Financial Group, Inc. operates as the...
# LH                67000.0  Labcorp Holdings Inc. provides laboratory serv...
# ...                   ...                                                ...
# CZR               51000.0  Caesars Entertainment, Inc. operates as a gami...
# BWA               39900.0  BorgWarner Inc., together with its subsidiarie...
# QRVO               8700.0  Qorvo, Inc. engages in development and commerc...
# FMC                5800.0  FMC Corporation, an agricultural sciences comp...
# AMTM                  NaN  Amentum Holdings, Inc. provides engineering an...
#
#           Weight
# Symbol
# FSLR    0.000351
# BF-B    0.000348
# LDOS    0.000348
# CFG     0.000345
# LH      0.000344
# ...          ...
# CZR     0.000125
# BWA     0.000125
# QRVO    0.000120
# FMC     0.000113
# AMTM    0.000084
#
# [128 rows x 15 columns]

# %%
properties={'Company Name':lambda x:x.info.get('longName'),'Sector':lambda x:x.info.get('sector'),'Market Cap':lambda x:x.info.get('marketCap')}

def stock_list_annotation(annotated_list, client, nation, output_file,to_add=['Company Name','Summary', 'Market0 Cap'],sleep_params=(1,10)):
    """Get company data with real-time CSV output"""
    def get_market_cap_formatted(market_cap):
        """Convert market cap to readable format"""
        if not market_cap:
            return 'N/A'
        billion = 1_000_000_000
        if market_cap >= billion:
            return f"${round(market_cap/billion, 1)}B"
        else:
            return f"${round(market_cap/1_000_000, 1)}M"
    #output_file="data/"+output_file_name+'_annotation.csv'
    fieldnames = ['Ticker']+to_add+list(annotated_list.columns)
    file_exists = os.path.exists(output_file)
    
    with open(output_file, 'a', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        if not file_exists:
            writer.writeheader()

        for ticker,info in annotated_list.iterrows():
            try:
                stock = yf.Ticker(ticker+nation_ending[nation])
                data = stock.history(period='1d', interval='1m')
                #record=info.copy(deep=True)
                
                record = {
                    'Ticker': ticker
                }
                for k in to_add:
                    if k in properties:
                        record[k]=properties[k](stock)
                if 'Summary' in to_add:
                    record['Summary']=summary(record['Company Name'],nation,client)
                print(record['Summary'])
                record.update(info.to_dict())
                writer.writerow(record)  # Immediate write
                csvfile.flush()  # Force OS-level write

            except Exception as e:
                print(f"Error {ticker}: {str(e)}")
                writer.writerow({'Ticker': ticker})  # Partial write

            sleep_time=np.random.gamma(*sleep_params)
            print(sleep_time)
            time.sleep(sleep_time)

# %%
stock_list_annotation(annotated_list.iloc[374:,], client,'US', 'data/sp500_annotation_1.csv')
# Out:
# First Solar, Inc. is an American solar technology company that designs, manufactures, and markets photovoltaic solar modules.
#
# 11.656417048960437
# Brown-Forman manufactures, bottles, and markets a range of alcoholic beverages, including whiskies, tequila, vodka, and wine.
#
# 18.079567392438456
# Leidos Holdings, Inc. provides technology and engineering services and solutions, including data analytics, cybersecurity, and enterprise IT, to various industries.
#
# 4.223072953171488
# Citizens Financial Group, headquartered in Providence, RI, offers retail and commercial banking products/services to individuals, small businesses, and institutions.
#
# 17.348856214199774
# Labcorp provides clinical laboratory services and end-to-end drug development support, offering a range of diagnostic technologies and testing services.
#
# 36.543242700006964
# VeriSign is a global provider of internet infrastructure and domain name registry services, ensuring the security, stability, and resiliency of the Domain Name System (DNS).
#
# 29.584370004702333
# International Paper is a global producer of sustainable packaging, pulp, and other fiber-based products, and one of the world's largest recyclers.
#
# 11.050602588855698
# Essex Property Trust is a REIT that acquires, develops, redevelops, and manages apartment communities primarily on the West Coast.
#
# 11.003973044228841
# Insulet Corporation develops, manufactures, and markets the Omnipod Insulin Management System for people with insulin-dependent diabetes.
#
# 26.58895740476288
# The Cooper Companies, Inc. is a medical device company focused on ophthalmology and surgical markets, manufacturing contact lenses and women's health products.
#
# 10.13020396751193
# Super Micro Computer, Inc. (Supermicro) provides high-performance server and storage solutions for various markets, including cloud computing, AI, and data centers.
#
# 9.246599247079264
# Seagate Technology provides mass-data storage infrastructure solutions, including hard disk drives and solid state drives, serving various industries globally.
#
# 26.516499004138765
# Mid-America Apartment Communities (MAA) is a real estate investment trust that owns, operates, acquires, and develops multifamily apartment communities, primarily in the Southeastern and Southwestern United States.
#
# 15.374988059204846
# FactSet is a financial data and software company providing integrated analytics and information to financial professionals and investors.
#
# 15.664308742984907
# NRG Energy is an integrated energy company involved in energy generation and retail electricity, producing power from various sources and providing energy and home services to residential, commercial, and industrial customers.
#
# 6.205135043084148
# Best Buy is a multinational retailer of consumer electronics, computing, appliances, and related services.
#
# 10.690063397473144
# Snap-on Incorporated designs, manufactures, and markets high-end tools and equipment for professional use, primarily in the transportation industry.
#
# 10.747258391632437
# Loews Corporation is a diversified holding company with businesses in the insurance, energy, hospitality, and packaging industries.
#
# 13.499042893637421
# Principal Financial Group, Inc. is a global financial company offering a range of products and services including retirement, asset management, and insurance to businesses, individuals, and institutions.
#
# 24.108783949351228
# Steel Dynamics is a large US steel producer and metal recycler utilizing electric arc furnace (EAF) technology.
#
# 22.954178400729603
# Trimble Inc. is a technology company providing software, hardware, and services for industries like construction, agriculture, and geospatial, connecting the physical and digital worlds.
#
# 14.739493844952401
# Omnicom Group Inc. is a global marketing and corporate communications company providing advertising, strategic media planning, precision marketing, and other specialty services to over 5,000 clients in more than 70 countries.
#
# 14.94974948063102

# %%
res
# Out:
#      Ticker                                  Company Name              Sector  \
# 0    TESTER                                           N/A                 N/A
# 1       MMM                                    3M Company         Industrials
# 2       AOS                       A. O. Smith Corporation         Industrials
# 3       ABT                           Abbott Laboratories          Healthcare
# 4      ABBV                                   AbbVie Inc.          Healthcare
# ..      ...                                           ...                 ...
# 382     PRU                    Prudential Financial, Inc.  Financial Services
# 383     PEG  Public Service Enterprise Group Incorporated           Utilities
# 384     PSA                                Public Storage         Real Estate
# 385     PHM                              PulteGroup, Inc.   Consumer Cyclical
# 386     PVH                                     PVH Corp.   Consumer Cyclical
#
#     Market Cap                                            Summary
# 0          N/A  I lack the information to answer. I need the c...
# 1       $82.8B  3M is a multinational conglomerate that manufa...
# 2        $9.5B  A. O. Smith is a global manufacturer of reside...
# 3      $229.1B  Abbott Laboratories is a global healthcare com...
# 4      $338.8B  AbbVie is a global biopharmaceutical company t...
# ..         ...                                                ...
# 382     $40.4B  Prudential Financial, Inc. is a global financi...
# 383     $41.9B  Public Service Enterprise Group (PSEG) is a di...
# 384     $52.9B  Public Storage is the world's largest owner, o...
# 385     $22.8B  PulteGroup, Inc. is a homebuilder in the Unite...
# 386      $4.4B  PVH Corp. is a fashion company that designs an...
#
# [387 rows x 5 columns]

# %%
res.to_csv(list_name+'_annotation.csv', index=False)

# %%
# list_name='ftse250'


# # ending=''
# filel=open('../gathering/data/'+list_name+'.txt','a+')
# filel.seek(0)
# stocklist=filel.read().splitlines()
# filel.close()

# %%
res=stock_list_annotation(stocklist,client,'UK')

# %%
# def stock_list_annotation(tickers, client,nation):
#     """Get top N intraday losers from a predefined S&P 500 ticker list with company details
    
#     Returns DataFrame with company name, sector, market cap, current price, and percentage change.
#     Includes random sleep intervals between API calls to prevent rate limiting.
#     """
#     losers = []
#     ending=nation_ending[nation]

    
#     for ticker in tickers:
#         print(ticker)
#         try:
#             #Random sleep between 0 and 3 seconds
            


#             stock = yf.Ticker(ticker+ending)
#             data = stock.history(period='1d', interval='1m')
#             dic={
#                 'Ticker': ticker,
#                 'Company Name': stock.info.get('longName', 'N/A'),
#                 'Sector': stock.info.get('sector', 'N/A'),
#                 'Market Cap': get_market_cap_formatted(stock.info.get('marketCap', None)),
#             }

#             dic['Summary']=summary(dic['Company Name'],nation,client)
#             print(dic['Summary'])
            
#         except Exception as e:
#             dic=dict()
#         losers.append(dic)
#         sleep_time=np.random.gamma(4,5)
#         print(sleep_time)
#         time.sleep(sleep_time)
#     losers_df = pd.DataFrame(losers)
#     if len(losers_df) == 0:
#         return pd.DataFrame(columns=['Ticker', 'Company Name', 'Sector', 'Market Cap', 'Summary'])
    
#     #losers_df = losers_df.sort_values(by='% Change')
#     return losers_df[['Ticker', 'Company Name', 'Sector', 'Market Cap', 'Summary']].reset_index(drop=True)

# %%
# annotated_list=pd.read_csv('data/sp500_annotation.csv')
# annotated_list=annotated_list.set_index('Symbol')
# annotated_list.to_csv('data/sp500_annotation.csv')
# list_name='ftse100'

# list_name='SP500'
# # ending=''
# filel=open('../gathering/data/'+list_name+'.txt','a+')
# filel.seek(0)
# stocklist=filel.read().splitlines()
# filel.close()
